# %%
import pandas as pd
from pathlib import Path

# %%
SOURCE_DIR = Path('../files/output/csv_output/runs_results/')
#TARGET_DIR = Path('../files/output/csv_output/treat2run')
RAW_CSV = SOURCE_DIR/'47-185-221-361-548_ex.csv'

# %%
# 1. Reading raw 2_run csv
df = pd.read_csv(RAW_CSV, index_col=None)
df
# Out:
#        from_city_id to_city_id  from_id                    from_node  to_id  \
# 0                47        216       -1                       Cancun     -1
# 1                47        216       -1                   San Lázaro     -1
# 2                47        216       -1                  Mexico City    297
# 3                47        216      297  Prague Airport Terminal 1/2    216
# 4                47        216       -1                  Mexico City     -1
# ...             ...        ...      ...                          ...    ...
# 75712           169        548      169                  Esbjerg St.     -1
# 75713           169        548       -1               Lunderskov St.     -1
# 75714           169        548       -1                  Gråsten St.     -1
# 75715           169        548       -1        Sønderborg Busstation     -1
# 75716           169        548       -1                   Sonderborg     -1
#
# ...

# %%
# How many duplicates
dupls = df.duplicated()
dupls.value_counts()
# Out:
# False    74957
# True       564
# dtype: int64

# %%
# 2. Removing full duplicates
df.drop_duplicates(inplace=True, ignore_index=True)
df
# Out:
#        from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 0                47        216       -1     -1             2             -1
# 1                47        216       -1     -1             2              0
# 2                47        216       -1    297             1            418
# 3                47        216      297    216             2              5
# 4                47        216       -1     -1             1            502
# ...             ...        ...      ...    ...           ...            ...
# 74952           169        548      169     -1             3              9
# 74953           169        548       -1     -1             3             12
# 74954           169        548       -1     -1             2              3
# 74955           169        548       -1     -1             2              2
# 74956           169        548       -1     -1             1            379
#
#        price_min currency  duration_min
# ...

# %%
control_ids = (47, 185, 221, 361, 548)

# %%
df_47 = df[((df['from_city_id'] == 47) | (df['to_city_id'] == 47)) & (df['transport_id'] == 1)]
df_47
# Out:
#       from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 2               47        216       -1    297             1            418
# 4               47        216       -1     -1             1            502
# 7               47        216       -1    266             1            376
# 12              47        216       -1    160             1            543
# 16              47        216       -1    247             1            209
# ...            ...        ...      ...    ...           ...            ...
# 5331            47         51       -1     -1             1            532
# 5335            47         51       -1     -1             1            497
# 5339            47         51       -1     89             1            532
# 5342            47         51       -1     -1             1            639
# 5345            47         51       -1     -1             1            639
#
#       price_min currency  duration_min
# ...

# %%
df_47[df_47['from_id'] == -1]
# Out:
#       from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 2               47        216       -1    297             1            418
# 4               47        216       -1     -1             1            502
# 7               47        216       -1    266             1            376
# 12              47        216       -1    160             1            543
# 16              47        216       -1    247             1            209
# ...            ...        ...      ...    ...           ...            ...
# 5331            47         51       -1     -1             1            532
# 5335            47         51       -1     -1             1            497
# 5339            47         51       -1     89             1            532
# 5342            47         51       -1     -1             1            639
# 5345            47         51       -1     -1             1            639
#
#       price_min currency  duration_min
# ...

# %%
df_47[df_47['to_id'] == -1]
# Out:
#       from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 4               47        216       -1     -1             1            502
# 44              47        174       -1     -1             1            500
# 59              47        137       -1     -1             1            380
# 62              47        137       -1     -1             1            350
# 66              47        137       -1     -1             1            500
# ...            ...        ...      ...    ...           ...            ...
# 5328            47         51       -1     -1             1            781
# 5331            47         51       -1     -1             1            532
# 5335            47         51       -1     -1             1            497
# 5342            47         51       -1     -1             1            639
# 5345            47         51       -1     -1             1            639
#
#       price_min currency  duration_min
# ...

# %%
df_47[df_47['to_city_id'] == '42']
# Out:
#       from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 2614            47         42       -1     42             1            185
# 2615            47         42       -1     -1             1            185
# 2617            47         42       -1     42             1            203
# 2619            47         42       -1     -1             1            305
# 2622            47         42       -1     -1             1            194
#
#       price_min currency  duration_min
# 2614        NaN      NaN           280
# 2615        NaN      NaN           284
# 2617        NaN      NaN           402
# 2619        NaN      NaN           436
# 2622        NaN      NaN           387

# %%
df_47[df_47['price_min_EUR'] == -1]
# Out:
#       from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 72              47        134       -1    134             1             -1
# 73              47        134       -1    309             1             -1
# 184             47        358       -1    147             1             -1
# 186             47        358       -1     -1             1             -1
# 189             47        358       -1     -1             1             -1
# ...            ...        ...      ...    ...           ...            ...
# 5313            47        294       -1    302             1             -1
# 5315            47        294       -1    236             1             -1
# 5316            47        294       -1    353             1             -1
# 5319            47        294       -1    368             1             -1
# 5320            47        294       -1    247             1             -1
#
#       price_min currency  duration_min
# ...

# %%
df_47['currency'].value_counts()
# Out:
# UAH    197
# HRK     31
# SAR     16
# AED     12
# LKR      7
# MAD      3
# ARS      3
# Name: currency, dtype: int64

# %%
df_185 = df[((df['from_city_id'] == 185) | (df['to_city_id'] == 185))]
df_185
# Out:
#        from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 10293           185         47       -1     -1             2              2
# 10294           185         47       -1    122             3             18
# 10295           185         47      122     -1             1            415
# 10296           185         47       -1     -1             2             -1
# 10297           185         47       -1     -1             2             -1
# ...             ...        ...      ...    ...           ...            ...
# 20098           185         24      120     -1             3             -1
# 20099           185         24       -1    243             3             -1
# 20100           185         24      243     24             1             -1
# 20101           185         24      225     -1             1             -1
# 20102           185         24       -1     24             2             -1
#
#        price_min currency  duration_min
# ...

# %%
df_185[(df_185['from_id'] > -1) & (df_185['to_id'] > -1) & (df_185['price_min_EUR'] > -1)]#& (df_185['from_id'] != df_185['to_id'])]
# Out:
#        from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 10305           185         47      142    142             3             13
# 10923           185         81      225     81             1            360
# 10924           185         81       81     81             2              2
# 10926           185         81      122     81             1            443
# 10928           185         81      225     81             1            406
# ...             ...        ...      ...    ...           ...            ...
# 20064           185        176      225    176             1             45
# 20067           185        176      243    176             1             55
# 20070           185        176      165    176             1             60
# 20073           185        176      225    367             2            130
# 20074           185        176      367    321             3             75
#
#        price_min currency  duration_min
# ...

# %%
df_185[(df_185['from_id'] == -1) & (df_185['to_id'] > -1) & (df_185['price_min_EUR'] > -1)]
# Out:
#        from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 10294           185         47       -1    122             3             18
# 10298           185         47       -1    225             3             46
# 10301           185         47       -1    120             3             39
# 10304           185         47       -1    142             3             34
# 10309           185         47       -1    311             3             34
# ...             ...        ...      ...    ...           ...            ...
# 20066           185        176       -1    243             3             10
# 20072           185        176       -1    225             2              7
# 20076           185        176       -1    176            10             85
# 20078           185        176       -1    248             2             19
# 20081           185        176       -1    321             2             35
#
#        price_min currency  duration_min
# ...

# %%
df_185[(df_185['from_id'] > -1) & (df_185['to_id'] == -1) & (df_185['price_min_EUR'] > -1)]
# Out:
#        from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 10295           185         47      122     -1             1            415
# 10299           185         47      225     -1             3              5
# 10300           185         47      225     -1             1            415
# 10302           185         47      120     -1             3              3
# 10303           185         47      120     -1             1            391
# ...             ...        ...      ...    ...           ...            ...
# 20075           185        176      321     -1             3             13
# 20077           185        176      225     -1             2            110
# 20079           185        176      248     -1             2             45
# 20080           185        176      225     -1             2            150
# 20082           185        176      321     -1             2             11
#
#        price_min currency  duration_min
# ...

# %%
df_185[(df_185['from_id'] == -1) & (df_185['to_id'] == -1) & (df_185['price_min_EUR'] > -1)]
# Out:
#        from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 10293           185         47       -1     -1             2              2
# 10308           185         47       -1     -1             3             32
# 10312           185         47       -1     -1             2              5
# 10920           185         81       -1     -1             2              2
# 10942           185        242       -1     -1             2              2
# ...             ...        ...      ...    ...           ...            ...
# 20038           185        301       -1     -1             2              2
# 20039           185        301       -1     -1             3             30
# 20046           185        176       -1     -1             2              2
# 20068           185        176       -1     -1             3             50
# 20071           185        176       -1     -1             2              2
#
#        price_min currency  duration_min
# ...

# %%
df_185[(df_185['from_id'] > -1) & (df_185['to_id'] > -1) & (df_185['price_min_EUR'] == -1)]
# Out:
#        from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 10964           185        242      329    242             3             -1
# 10970           185        242      329    242             2             -1
# 10974           185        242      347    242             2             -1
# 10982           185        368      122    368             1             -1
# 10983           185        368      368    368             2             -1
# ...             ...        ...      ...    ...           ...            ...
# 20092           185         24      122     24             1             -1
# 20094           185         24      225     24             1             -1
# 20095           185         24      225    225             3             -1
# 20097           185         24      225     24             1             -1
# 20100           185         24      243     24             1             -1
#
#        price_min currency  duration_min
# ...

# %%
df_221 = df[((df['from_city_id'] == 221) | (df['to_city_id'] == 221))]
df_221
# Out:
#        from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 7528            221         47       -1    225             3            117
# 7529            221         47      225     -1             3              5
# 7530            221         47      225     -1             1            415
# 7531            221         47       -1     -1             2             -1
# 7532            221         47       -1     -1             2             -1
# ...             ...        ...      ...    ...           ...            ...
# 39658           221        187      120    187             1             35
# 39659           221        187      122    342             1             25
# 39660           221        187      342    342             2              2
# 39661           221        187      342     -1             3             19
# 39662           221        187       -1    187             3             30
#
#        price_min currency  duration_min
# ...

# %%
df_221[df_221['from_id'] == -1]
# Out:
# Empty DataFrame
# Columns: [from_city_id, to_city_id, from_id, to_id, transport_id, price_min_EUR, price_min, currency, duration_min]
# Index: []

# %%
df_221[df_221['to_id'] == -1]
# Out:
#        from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 7530            221         47      225     -1             1            415
# 7535            221         47      122     -1             1            415
# 7540            221         47      142     -1             1            415
# 7541            221         47      225     -1             1            415
# 7546            221         47      265     -1             1            586
# ...             ...        ...      ...    ...           ...            ...
# 39367           221         16      225     -1             1            340
# 39383           221         16      225     -1             1            340
# 39571           221        240      122     -1             1             21
# 39614           221         67      225     -1             1            705
# 39629           221         67      225     -1             1            451
#
#        price_min currency  duration_min
# ...

# %%
df_221[df_221['price_min_EUR'] == -1]
# Out:
#        from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 29979           221         84      225     84             1             -1
# 29982           221         84      225     84             1             -1
# 29986           221         84      120     84             1             -1
# 29990           221         84      265     84             1             -1
# 29992           221         84      122     84             1             -1
# ...             ...        ...      ...    ...           ...            ...
# 39469           221        279      122    213             1             -1
# 39471           221        279      265    348             1             -1
# 39477           221        279      225    213             1             -1
# 39481           221        279      225    213             1             -1
# 39482           221        279      265    214             1             -1
#
#        price_min currency  duration_min
# ...

# %%
df_361 = df[((df['from_city_id'] == 361) | (df['to_city_id'] == 361)) & (df['transport_id'] == 1)]
df_361
# Out:
#        from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 6678            361         47      161     -1             1            244
# 6685            361         47      111     -1             1            391
# 6687            361         47      174     -1             1            229
# 6690            361         47      246     -1             1            537
# 6695            361         47      116     -1             1            342
# ...             ...        ...      ...    ...           ...            ...
# 58055           361        296      161    348             1             67
# 58071           361        184      161    184             1             91
# 58073           361        184      161    166             1             23
# 58079           361        184      111    184             1             34
# 58080           361        184      111    166             1             40
#
#        price_min currency  duration_min
# ...

# %%
df_361[df_361['from_id'] == -1]
# Out:
# Empty DataFrame
# Columns: [from_city_id, to_city_id, from_id, to_id, transport_id, price_min_EUR, price_min, currency, duration_min]
# Index: []

# %%
df_361[df_361['to_id'] == -1]
# Out:
#        from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 6678            361         47      161     -1             1            244
# 6685            361         47      111     -1             1            391
# 6687            361         47      174     -1             1            229
# 6690            361         47      246     -1             1            537
# 6695            361         47      116     -1             1            342
# ...             ...        ...      ...    ...           ...            ...
# 58033           361        554      174     -1             1            342
# 58036           361        554      161     -1             1            273
# 58039           361        554      174     -1             1            285
# 58040           361        554      111     -1             1            364
# 58041           361        554      111     -1             1            444
#
#        price_min currency  duration_min
# ...

# %%
df_361[df_361['price_min_EUR'] == -1]
# Out:
#        from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 49660           361        352      161    248             1             -1
# 49668           361        352      172    352             1             -1
# 49670           361        352      172    248             1             -1
# 49675           361        352      111    248             1             -1
# 49676           361        352      111    129             1             -1
# ...             ...        ...      ...    ...           ...            ...
# 57979           361         86      174     -1             1             -1
# 57980           361         86      161     -1             1             -1
# 57985           361         86      111     86             1             -1
# 57986           361         86      161     84             1             -1
# 57993           361         86      172     86             1             -1
#
#        price_min currency  duration_min
# ...

# %%
df_548 = df[((df['from_city_id'] == 548) | (df['to_city_id'] == 548)) & (df['transport_id'] == 1)]
df_548
# Out:
#        from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 6390            548         47       -1     -1             1           1025
# 6393            548         47       -1     -1             1            927
# 6396            548         47       -1     -1             1            879
# 6399            548         47       -1     -1             1            976
# 26648           548        185       -1    225             1             -1
# ...             ...        ...      ...    ...           ...            ...
# 70930           548         76       -1     76             1             -1
# 70933           548         33       -1     33             1            554
# 70947           548        176       -1    176             1            750
# 70949           548        176       -1    227             1            950
# 70952           548        176       -1    228             1            700
#
#        price_min currency  duration_min
# ...

# %%
df_548[df_548['to_city_id'] == '95']
# Out:
#        from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 67155           548         95       -1     95             1             -1
# 67157           548         95       -1     69             1             -1
# 67160           548         95       -1     -1             1             -1
# 67164           548         95       -1     -1             1             -1
#
#        price_min currency  duration_min
# 67155     2100.0      AED           744
# 67157     1000.0      AED           875
# 67160     2900.0      AED           639
# 67164     1600.0      AED          1450

# %%
df_548[df_548['from_id'] == -1]
# Out:
#        from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 6390            548         47       -1     -1             1           1025
# 6393            548         47       -1     -1             1            927
# 6396            548         47       -1     -1             1            879
# 6399            548         47       -1     -1             1            976
# 26648           548        185       -1    225             1             -1
# ...             ...        ...      ...    ...           ...            ...
# 70930           548         76       -1     76             1             -1
# 70933           548         33       -1     33             1            554
# 70947           548        176       -1    176             1            750
# 70949           548        176       -1    227             1            950
# 70952           548        176       -1    228             1            700
#
#        price_min currency  duration_min
# ...

# %%
df_548[df_548['to_id'] == -1]
# Out:
#        from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 6390            548         47       -1     -1             1           1025
# 6393            548         47       -1     -1             1            927
# 6396            548         47       -1     -1             1            879
# 6399            548         47       -1     -1             1            976
# 66770           548        186       -1     -1             1            700
# ...             ...        ...      ...    ...           ...            ...
# 70887           548        553       -1     -1             1            569
# 70888           548        553       -1     -1             1            330
# 70893           548         58       -1     -1             1            785
# 70907           548        286       -1     -1             1            550
# 70922           548        356       -1     -1             1            406
#
#        price_min currency  duration_min
# ...

# %%
df_548[df_548['price_min_EUR'] == -1]
# Out:
#        from_city_id to_city_id  from_id  to_id  transport_id  price_min_EUR  \
# 26648           548        185       -1    225             1             -1
# 26651           548        185       -1    225             1             -1
# 26654           548        185       -1    122             1             -1
# 26656           548        185       -1    142             1             -1
# 26660           548        185       -1    120             1             -1
# ...             ...        ...      ...    ...           ...            ...
# 70721           548        313       -1    225             1             -1
# 70723           548        313       -1    243             1             -1
# 70726           548        313       -1    122             1             -1
# 70728           548        313       -1    120             1             -1
# 70930           548         76       -1     76             1             -1
#
#        price_min currency  duration_min
# ...
