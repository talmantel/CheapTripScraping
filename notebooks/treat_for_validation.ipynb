# %%
import pandas as pd
from pathlib import Path

# %%
SOURCE_DIR = Path('../output/csv_output/')
raw_csv = Path(SOURCE_DIR/'all_direct_routes_raw.csv')

# %%
# 1. Reading raw 2_run csv
df_raw = pd.read_csv(raw_csv, usecols=['from_id', 'to_id', 'transport_id', 'price_min_EUR', 
                                       'duration_min', 'distance_km', 'frequency_tpw'], )
df_raw
# Out:
#         from_id  to_id  transport_id  price_min_EUR  duration_min  \
# 0           280    331             2             17           415
# 1           280    207             2             23           330
# 2           107    297             1             46           180
# 3           297    216             2              5           100
# 4           107    108             3             16            78
# ...         ...    ...           ...            ...           ...
# 966477      348    117             2             70          1370
# 966478      212    297             2             47          1070
# 966479      297    117             2            177          1530
# 966480      364    123             3             16           685
# 966481      349    117             2              5           144
#
#         distance_km  frequency_tpw
# 0               441              6
# 1               439              7
# 2               828             29
# 3               122             81
# 4               138            231
# ...             ...            ...
# 966477         1450              4
# 966478         1085              7
# 966479         1714              3
# 966480          904              7
# 966481          135             49
#
# [966482 rows x 7 columns]

# %%
df_val = df_raw.drop_duplicates()
df_val
# Out:
#         from_id  to_id  transport_id  price_min_EUR  duration_min  \
# 0           280    331             2             17           415
# 1           280    207             2             23           330
# 2           107    297             1             46           180
# 3           297    216             2              5           100
# 4           107    108             3             16            78
# ...         ...    ...           ...            ...           ...
# 966393      118    171             1             51           875
# 966407      163    156             1            130           695
# 966456      129    240             2             27           735
# 966466      118     78             1            158           390
# 966471       42    215             1            460           660
#
#         distance_km  frequency_tpw
# 0               441              6
# 1               439              7
# 2               828             29
# 3               122             81
# 4               138            231
# ...             ...            ...
# 966393         2295              8
# 966407         2729             36
# 966456          928             28
# 966466         2058             14
# 966471         7067            109
#
# [143737 rows x 7 columns]

# %%
#df_val.to_csv(SOURCE_DIR/'all_direct_routes_validation.csv', index=False)
