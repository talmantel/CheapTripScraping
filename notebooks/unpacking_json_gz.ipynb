# %%
from currency_converter import CurrencyConverter, ECB_URL, SINGLE_DAY_ECB_URL
import compress_json
from pathlib import Path

# %%
from currency_converter import CurrencyConverter, SINGLE_DAY_ECB_URL
cc = CurrencyConverter(SINGLE_DAY_ECB_URL)

# %%
x, curr = 95, 'USD'

print(round(cc.convert(x, curr), 3), round(cc.convert(x, curr)))
# Out:
# 88.785 89

# %%
x, from_curr, to_curr = 1600, 'SEK', 'EUR'

print(round(cc.convert(x, from_curr, to_curr), 2), round(cc.convert(x, from_curr, to_curr)))
# Out:
# 140.59 141

# %%
# necessary pathes setting up
PATH_JSON_OUTPUT = Path("../files/output/json_output/2_run_jsons_r2r")

# %%
#way = '259-Marseille-343-Tivat'
way = '225-London-153-Cluj-Napoca'
filepath = f'{PATH_JSON_OUTPUT}/{way}.json.gz'
pathes = compress_json.load(filepath) # for loading a gzip file

# %%
for path_id, path in enumerate(pathes):
    print(path_id, '\n' '\t', path)

# %%
#Unpacking nested lists from scraped json ***DON`T TOUCH***
for path_id, path in enumerate(pathes):
    for item, route in enumerate(path):
        print(path_id, '\n\t', item, '\t', route)

# %%
print('transporter: ', pathes[0][8][0][10][8][0][0])
print('web-page: ', pathes[0][8][0][10][8][0][2])
print('duration, min: ', pathes[0][8][0][10][8][0][4]/60)
print('distance, km: ', pathes[0][8][0][10][8][0][5])
print('frequency, times per week:', pathes[0][8][0][10][8][0][6])
#print('comment:', pathes[3][8][0][10][8][0][9][0])
print('stations', pathes[0][8][0][10][8][0][22][:])
print()
for i, item in enumerate(pathes[0][8][0][10][8][0]):
    print(i, item)
# Out:
# transporter:  Dockland Light Railway (DLR)
# web-page:  https://tfl.gov.uk/modes/dlr/?cid=dlr
# duration, min:  21.0
# distance, km:  9.985463
# frequency, times per week: 850
# stations [[['station', 'Bank DLR Station', 51.51217, -0.08791, 'GB', 'Europe/London'], '', 0, 'True', 'False'], [['station', 'Shadwell DLR Station', 51.51164, -0.05634, 'GB', 'Europe/London'], '', 4, 'True', 'False'], [['station', 'Limehouse DLR Station', 51.51234, -0.03961, 'GB', 'Europe/London'], 6, 6, 'False', 'False'], [['station', 'Westferry DLR Station', 51.50941, -0.02658, 'GB', 'Europe/London'], 8, 8, 'False', 'False'], [['station', 'Poplar DLR Station', 51.50769, -0.01753, 'GB', 'Europe/London'], 9, 10, 'False', 'False'], [['station', 'Blackwall DLR Station', 51.50798, -0.00664, 'GB', 'Europe/London'], 11, 11, 'False', 'False'], [['station', 'East India DLR Station', 51.50991, -0.00171, 'GB', 'Europe/London'], 12, 13, 'False', 'False'], [['station', 'Canning Town DLR Station', 51.51447, 0.00786, 'GB', 'Europe/London'], 14, 15, 'False', 'False'], [['station', 'West Silvertown DLR Station', 51.50239, 0.02245, 'GB', 'Europe/London'], 17, 17, 'False', 'False'], [['station', 'Pontoon Dock DLR Station', 51.50221, 0.03213, 'GB', 'Europe/London'], 19, 19, 'False', 'False'], [['station', 'London City Airport DLR Station', 51.50341, 0.04875, 'GB', 'Europe/London'], 21, 21, 'False', 'False']]
#
# 0 Dockland Light Railway (DLR)
# 1 //static.r2r.io/logos/Trains/96/_DOCKLAND_LIGHT_RAILWAY_DLR_201811161410.png
# 2 https://tfl.gov.uk/modes/dlr/?cid=dlr
# 3 tfl.gov.uk
# 4 1260
# 5 9.985463
# 6 850
# 7 Dlr
# 8 [['https://tfl.gov.uk/modes/dlr/?cid=dlr', 'Dockland Light Railway (DLR)', 'Website', 'Dockland Light Railway (DLR)', '', '', '', '', '']]
# 9 []
# 10 0343 222 1234
# 11
# 12
# 13 [['//static.r2r.io/transitimages/148632927.jpg', 333, 250], ['//static.r2r.io/transitimages/1767636867.jpg', 333, 250], ['//static.r2r.io/transitimages/261050284.jpg', 374, 250], ['//static.r2r.io/transitimages/1545564859.jpg', 374, 250], ['//static.r2r.io/transitimages/1076323014.jpg', 333, 250], ['//static.r2r.io/transitimages/1112160344.jpg', 187, 250]]
# 14 []
# 15 [[1, 'USD', 1.83, 'False', ''], [2, 'USD', 2.08, 'False', ''], [6, 'USD', 5.99, 'False', '']]
# 16 [[1, 'GBP', 1.5, 'False', ''], [2, 'GBP', 1.7, 'False', ''], [5, 'GBP', 4.9, 'False', '']]
# 17 [['Oyster or Contactless Off Peak Time Fare', [[2, 'USD', 1.83, 'False', ''], [2, 'USD', 1.83, 'False', ''], [2, 'USD', 1.83, 'False', '']]], ['Oyster or Contactless Peak Time Fare', [[3, 'USD', 2.08, 'False', ''], [3, 'USD', 2.08, 'False', ''], [3, 'USD', 2.08, 'False', '']]], ['Cash Fare ', [[6, 'USD', 5.99, 'False', ''], [6, 'USD', 5.99, 'False', ''], [6, 'USD', 5.99, 'False', '']]]]
# 18 [['Oyster or Contactless Off Peak Time Fare', [[2, 'GBP', 1.5, 'False', ''], [2, 'GBP', 1.5, 'False', ''], [2, 'GBP', 1.5, 'False', '']]], ['Oyster or Contactless Peak Time Fare', [[2, 'GBP', 1.7, 'False', ''], [2, 'GBP', 1.7, 'False', ''], [2, 'GBP', 1.7, 'False', '']]], ['Cash Fare ', [[5, 'GBP', 4.9, 'False', ''], [5, 'GBP', 4.9, 'False', ''], [5, 'GBP', 4.9, 'False', '']]]]
# 19 _DOCKLAND_LIGHT_RAILWAY_(DLR)
# 20 ['station', 'Bank DLR Station', 51.51217, -0.08791, 'GB', 'Europe/London']
# 21 ['station', 'London City Airport DLR Station', 51.50341, 0.04875, 'GB', 'Europe/London']
# 22 [[['station', 'Bank DLR Station', 51.51217, -0.08791, 'GB', 'Europe/London'], '', 0, 'True', 'False'], [['station', 'Shadwell DLR Station', 51.51164, -0.05634, 'GB', 'Europe/London'], '', 4, 'True', 'False'], [['station', 'Limehouse DLR Station', 51.51234, -0.03961, 'GB', 'Europe/London'], 6, 6, 'False', 'False'], [['station', 'Westferry DLR Station', 51.50941, -0.02658, 'GB', 'Europe/London'], 8, 8, 'False', 'False'], [['station', 'Poplar DLR Station', 51.50769, -0.01753, 'GB', 'Europe/London'], 9, 10, 'False', 'False'], [['station', 'Blackwall DLR Station', 51.50798, -0.00664, 'GB', 'Europe/London'], 11, 11, 'False', 'False'], [['station', 'East India DLR Station', 51.50991, -0.00171, 'GB', 'Europe/London'], 12, 13, 'False', 'False'], [['station', 'Canning Town DLR Station', 51.51447, 0.00786, 'GB', 'Europe/London'], 14, 15, 'False', 'False'], [['station', 'West Silvertown DLR Station', 51.50239, 0.02245, 'GB', 'Europe/London'], 17, 17, 'False', 'False'], [['station', 'Pontoon Dock DLR Station', 51.50221, 0.03213, 'GB', 'Europe/London'], 19, 19, 'False', 'False'], [['station', 'London City Airport DLR Station', 51.50341, 0.04875, 'GB', 'Europe/London'], 21, 21, 'False', 'False']]
# 23
# 24 []
# 25 []
# 26 [['DLR', '009999', 'FFFFFF']]
# 27 []
# 28 Gtfs

# %%
print('transporter: ', pathes[1][8][0][10][8][0][0])
print('web-page: ', pathes[1][8][0][10][8][0][2])
print('duration, min: ', pathes[1][8][0][10][8][0][4]/60)
print('distance, km: ', pathes[1][8][0][10][8][0][5])
print('frequency, times per week:', pathes[1][8][0][10][8][0][6]) # [10][7]
#print('comment:', pathes[3][8][0][10][8][0][9][0])
print('stations', pathes[1][8][0][10][8][0][22])
print()
for i, item in enumerate(pathes[1][8][0][10][8][0]):
    print(i, item)
# Out:
# transporter:  Heathrow Express
# web-page:  https://www.heathrowexpress.com/
# duration, min:  15.0
# distance, km:  23.14465
# frequency, times per week: 811
# stations [[['station', 'London Paddington Train Station', 51.51665, -0.176815, 'GB', 'Europe/London'], '', 0, 'True', 'False'], [['station', 'London Heathrow Airport T2 & 3 Train Station', 51.47211, -0.454587, 'GB', 'Europe/London'], 15, '', 'False', 'True']]
#
# 0 Heathrow Express
# 1 //static.r2r.io/logos/trains/heathrow.png
# 2 https://www.heathrowexpress.com/
# 3 heathrowexpress.com
# 4 900
# 5 23.14465
# 6 811
# 7 Heathrow Express, London Paddington - Heathrow Terminal 5
# 8 [['https://www.heathrowexpress.com/', 'heathrowexpress.com', 'Website', 'Heathrow Express', '', '', '', '', '']]
# 9 []
# 10 +44 345 600 1515
# 11 socialmedia@heathrowexpress.com
# 12
# 13 [['//static.r2r.io/transitimages/1929415465.jpg', 400, 250], ['//static.r2r.io/transitimages/32463799.jpg', 375, 250], ['//static.r2r.io/transitimages/1710137782.jpg', 375, 250], ['//static.r2r.io/transitimages/291211505.jpg', 375, 250], ['//static.r2r.io/transitimages/1347994115.jpg', 326, 250], ['//static.r2r.io/transitimages/973121632.jpg', 375, 250], ['//static.r2r.io/transitimages/2111750410.jpg', 333, 250], ['//static.r2r.io/transitimages/566032174.jpg', 187, 250], ['//static.r2r.io/transitimages/1752322813.jpg', 333, 250], ['//static.r2r.io/transitimages/398099721.jpg', 333, 250]]
# 14 []
# 15 [[26, 'USD', 26.65, 'False', ''], [30, 'USD', 30.58, 'False', ''], [40, 'USD', 38.76, 'False', '']]
# 16 [[21, 'GBP', 21.79, 'False', ''], [25, 'GBP', 25, 'False', ''], [35, 'GBP', 31.69, 'False', '']]
# 17 [['Off Peak Standard Ticket', [[27, 'USD', 26.65, 'False', ''], [27, 'USD', 26.65, 'False', ''], [27, 'USD', 26.65, 'False', '']]], ['Peak Standard Ticket', [[31, 'USD', 30.28, 'False', ''], [31, 'USD', 30.28, 'False', ''], [31, 'USD', 30.28, 'False', '']]], ['Business First Ticket', [[39, 'USD', 38.76, 'False', ''], [39, 'USD', 38.76, 'False', ''], [39, 'USD', 38.76, 'False', '']]]]
# 18 [['Off Peak Standard Ticket', [[22, 'GBP', 21.79, 'False', ''], [22, 'GBP', 21.79, 'False', ''], [22, 'GBP', 21.79, 'False', '']]], ['Peak Standard Ticket', [[25, 'GBP', 24.76, 'False', ''], [25, 'GBP', 24.76, 'False', ''], [25, 'GBP', 24.76, 'False', '']]], ['Business First Ticket', [[32, 'GBP', 31.69, 'False', ''], [32, 'GBP', 31.69, 'False', ''], [32, 'GBP', 31.69, 'False', '']]]]
# 19 _HEATHROW_EXPRESS
# 20 ['station', 'London Paddington Train Station', 51.51665, -0.176815, 'GB', 'Europe/London']
# 21 ['station', 'London Heathrow Airport T2 & 3 Train Station', 51.47211, -0.454587, 'GB', 'Europe/London']
# 22 [[['station', 'London Paddington Train Station', 51.51665, -0.176815, 'GB', 'Europe/London'], '', 0, 'True', 'False'], [['station', 'London Heathrow Airport T2 & 3 Train Station', 51.47211, -0.454587, 'GB', 'Europe/London'], 15, '', 'False', 'True']]
# 23
# 24 []
# 25 []
# 26 [['Heathrow Express', '5D226C', 'FFFFFF'], ['London Paddington - Heathrow Terminal 5', '', '']]
# 27 []
# 28 Gtfs

# %%
#print('booking web-page: ', pathes[7][8][-1][6])
print('transporter: ', pathes[6][8][0][10][8][0][0])
print('web-page: ', pathes[6][8][0][10][8][0][2])
print('duration, min: ', pathes[6][8][0][10][8][0][4]/60)
print('distance, km: ', pathes[6][8][0][10][8][0][5])
print('frequency, times per week:', pathes[6][8][0][10][8][0][6])
#print('comment:', pathes[6][8][0][10][8][0][9][0])
print('stations', pathes[6][8][0][10][8][0][22][0:3])

for i, item in enumerate(pathes[6][8][0][10][8][0]):
    print(i, item)
# Out:
# transporter:  Eurostar
# web-page:  https://www.eurostar.com/rw-en
# duration, min:  141.0
# distance, km:  450.3989
# frequency, times per week: 49
# stations [[['station', 'London St Pancras Intl', 51.53056, -0.12528, 'GB', 'Europe/Lisbon'], 0, 0, 'False', 'False'], [['station', 'Paris Nord', 48.88139, 2.35472, 'FR', 'Europe/Paris'], 141, 141, 'False', 'False']]
# 0 Eurostar
# 1 //static.r2r.io/logos/Trains/96/_EUROSTAR_201901211657.png
# 2 https://www.eurostar.com/rw-en
# 3 eurostar.com
# 4 8460
# 5 450.3989
# 6 49
# 7 Eil
# 8 [['https://www.eurostar.com/rw-en', 'Eurostar', 'Website', 'Eurostar', '', '', '', '', '']]
# 9 []
# 10 +44 343 218 6186
# 11
# 12 eurostar
# 13 [['//static.r2r.io/transitimages/869067909.jpg', 444, 250], ['//static.r2r.io/transitimages/169310527.jpg', 401, 250], ['//static.r2r.io/transitimages/466776257.jpg', 362, 250], ['//static.r2r.io/transitimages/1600770339.jpg', 375, 250], ['//static.r2r.io/transitimages/711325473.jpg', 187, 250], ['//static.r2r.io/transitimages/1703143847.jpg', 333, 250], ['//static.r2r.io/transitimages/43400525.jpg', 373, 250], ['//static.r2r.io/transitimages/1647926610.jpg', 333, 250], ['//static.r2r.io/transitimages/1724485518.jpg', 187, 250], ['//static.r2r.io/transitimages/115994450.jpg', 296, 250], ['//static.r2r.io/transitimages/335624019.jpg', 375, 250]]
# 14 [[['Eil'], [0, 0, 1, 0], ['Advance booking: <b>Compulsory</b>.']]]
# 15 [[120, 'USD', 126.62, 'False', ''], [200, 'USD', 199.99, 'False', ''], [380, 'USD', 374.78, 'False', '']]
# 16 [[110, 'EUR', 116.77, 'False', ''], [180, 'EUR', 184.43, 'False', ''], [350, 'EUR', 345.63, 'False', '']]
# 17 [['Business Premier', [[330, 'USD', 337.44, 'False', ''], [360, 'USD', 356.1, 'False', ''], [380, 'USD', 374.78, 'False', '']]], ['Standard', [[120, 'USD', 126.62, 'False', ''], [140, 'USD', 138.61, 'False', ''], [160, 'USD', 150.67, 'False', '']]], ['Standard Premier', [[170, 'USD', 178.45, 'False', ''], [200, 'USD', 199.99, 'False', ''], [230, 'USD', 221.37, 'False', '']]]]
# 18 [['Business Premier', [[310, 'EUR', 311.19, 'False', ''], [330, 'EUR', 328.4, 'False', ''], [350, 'EUR', 345.63, 'False', '']]], ['Standard', [[110, 'EUR', 116.77, 'False', ''], [130, 'EUR', 127.83, 'False', ''], [140, 'EUR', 138.95, 'False', '']]], ['Standard Premier', [[160, 'EUR', 164.57, 'False', ''], [180, 'EUR', 184.43, 'False', ''], [210, 'EUR', 204.15, 'False', '']]]]
# 19 _EUROSTAR
# 20 ['station', 'London St Pancras Intl', 51.53056, -0.12528, 'GB', 'Europe/Lisbon']
# 21 ['station', 'Paris Nord', 48.88139, 2.35472, 'FR', 'Europe/Paris']
# 22 [[['station', 'London St Pancras Intl', 51.53056, -0.12528, 'GB', 'Europe/Lisbon'], 0, 0, 'False', 'False'], [['station', 'Paris Nord', 48.88139, 2.35472, 'FR', 'Europe/Paris'], 141, 141, 'False', 'False']]
# 23
# 24 []
# 25 []
# 26 [['EIL', '', '']]
# 27 ['_EUROSTAR']
# 28 Gtfs

# %%
for i, path in enumerate(pathes[7][8]):
    for j, route in enumerate(path[10][8][0][22]):
        print(i, j, route[0][1])
# Out:
# 0 0 London
# 0 1 Brussels
# 0 2 Medenbach
# 0 3 Nuremberg A3
# 0 4 Linz
# 0 5 Viena- Hotel IBIS
# 0 6 Oradea
# 0 7 Cluj-Napoca
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[67], line 2
#       1 for i, path in enumerate(pathes[7][8]):
# ----> 2     for j, route in enumerate(path[10][8][0][22]):
#       3         print(i, j, route[0][1])
#
# IndexError: list index out of range

# %%
for path_id, path in enumerate(pathes):
    for route_id, route in enumerate(path[8][:-1]):
        if route[1] in ('bus', 'train'):
            print(path_id,'\t', route_id,'\t',route[1],'\t',route[10][:2],'\t',
                  route[10][8][0][6],'\t', route[10][7], '\t', route[10][8][0][0])#[8][0][0])
# Out:
# 0 	 0 	 train 	 [1260, 9.985463] 	 850 	 850 	 Dockland Light Railway (DLR)
# 0 	 4 	 bus 	 [900, 9.973733] 	 33 	 22 	 Alis Grup
# 1 	 0 	 train 	 [900, 23.14465] 	 811 	 1010 	 Heathrow Express
# 1 	 4 	 bus 	 [900, 9.973733] 	 33 	 22 	 Alis Grup
# 2 	 0 	 train 	 [1860, 46.5092] 	 616 	 858 	 Thameslink
# 2 	 2 	 bus 	 [360, 2.489367] 	 903 	 903 	 London General
# 2 	 6 	 bus 	 [900, 9.973733] 	 33 	 22 	 Alis Grup
# 3 	 0 	 train 	 [1980, 42.77863] 	 694 	 946 	 Southern Service
# 3 	 4 	 bus 	 [900, 9.973733] 	 33 	 22 	 Alis Grup
# 4 	 0 	 train 	 [2940, 58.83015] 	 291 	 291 	 Stansted Express
# 4 	 4 	 bus 	 [900, 9.973733] 	 33 	 22 	 Alis Grup
# 5 	 0 	 train 	 [1860, 46.5092] 	 616 	 858 	 Thameslink
# 5 	 2 	 bus 	 [360, 2.489367] 	 903 	 903 	 London General
# 5 	 6 	 bus 	 [420, 3.030476] 	 672 	 672 	 Tursib
# 5 	 8 	 bus 	 [11100, 179.7157] 	 14 	 14 	 Fany
# 6 	 0 	 train 	 [8460, 450.3989] 	 49 	 49 	 Eurostar
# 6 	 1 	 train 	 [20580, 834.4317] 	 1 	 1 	 TGV inOui
# 6 	 3 	 train 	 [5340, 147.161] 	 83 	 233 	 Deutsche Bahn Intercity-Express
# 6 	 4 	 train 	 [10440, 309.3982] 	 217 	 391 	 Railjet
# 6 	 5 	 train 	 [38460, 651.31] 	 7 	 7 	 ÖBB EuroCity
# 7 	 0 	 bus 	 [129960, 2203.091] 	 1 	 1 	 Trans Nicolaescu
# 8 	 0 	 train 	 [720, 9.27837] 	 538 	 830 	 Greater Anglia

# %%
pathes[8]
# Out:
# [0,
#  ['node', 'London Liverpool St', 51.51793, -0.08176, '', '', -1],
#  ['node', 'Cluj-Napoca', 46.76667, 23.6, 'RO', 'Europe/Bucharest', 2.5],
#  'Bus-and-ferry',
#  'Bus and ferry',
#  144960,
#  141360,
#  3600,
#  [['transit',
#    'train',
#    'purple',
#    720,
#    364.547,
#    9.27837,
#    ['station',
#     'London Liverpool Street',
#     51.51799,
#     -0.08143,
#     'GB',
#     'Europe/London'],
#    ['station', 'Tottenham Hale', 51.58831, -0.05993, 'GB', 'Europe/London'],
#    '',
#    'False',
#    [720,
#     9.27837,
#     ['station',
#      'London Liverpool Street',
#      51.51799,
#      -0.08143,
#      'GB',
#      'Europe/London'],
#     ['station', 'Tottenham Hale', 51.58831, -0.05993, 'GB', 'Europe/London'],
#     'train',
#     ['Commuter', ' Bicycles', ' Wheelchair'],
#     'London Liverpool Street - Hertford East',
#     830,
#     [['Greater Anglia',
#       '//static.r2r.io/logos/Trains/96/_NATIONAL_EXPRESS_EAST_ANGLIA_2017530164.png',
#       'https://www.greateranglia.co.uk',
#       'greateranglia.co.uk',
#       720,
#       9.27837,
#       538,
#       'London Liverpool Street - Bishops Stortford, London Liverpool Street - Broxbourne, London Liverpool Street - Cambridge, London Liverpool Street - Cambridge North, London Liverpool Street - Cheshunt, London Liverpool Street - Ely, London Liverpool Street - Hertford East, London Liverpool Street - Kings Lynn',
#       [['https://www.greateranglia.co.uk',
#         'greateranglia.co.uk',
#         'Website',
#         'GreaterAnglia',
#         '',
#         '',
#         '',
#         '',
#         ''],
#        ['http://ojp.nationalrail.co.uk/service/timesandfares/London%20Liverpool%20Street/Tottenham%20Hale/{day}{month}{year}/{hour}{minute}/dep',
#         'ojp.nationalrail.co.uk',
#         'Schedules at',
#         'National Rail',
#         '',
#         '',
#         '',
#         '',
#         '']],
#       [],
#       '',
#       '',
#       '',
#       [['//static.r2r.io/transitimages/1782398096.jpg', 497, 250],
#        ['//static.r2r.io/transitimages/1457501599.jpg', 187, 250],
#        ['//static.r2r.io/transitimages/394939643.jpg', 370, 250],
#        ['//static.r2r.io/transitimages/2000330244.jpg', 386, 250],
#        ['//static.r2r.io/transitimages/1983855368.jpg', 333, 250],
#        ['//static.r2r.io/transitimages/2141617341.jpg', 338, 250],
#        ['//static.r2r.io/transitimages/1882608752.jpg', 333, 250],
#        ['//static.r2r.io/transitimages/1738560853.jpg', 376, 250]],
#       [],
#       [[3, 'USD', 3.7, 'False', ''],
#        [4, 'USD', 4.36, 'False', ''],
#        [6, 'USD', 5.38, 'False', '']],
#       [[3, 'GBP', 3.03, 'False', ''],
#        [4, 'GBP', 3.56, 'False', ''],
#        [5, 'GBP', 4.4, 'False', '']],
#       [],
#       [],
#       '_NATIONAL_EXPRESS_EAST_ANGLIA',
#       ['station',
#        'London Liverpool Street',
#        51.51799,
#        -0.08143,
#        'GB',
#        'Europe/London'],
#       ['station', 'Tottenham Hale', 51.58831, -0.05993, 'GB', 'Europe/London'],
#       [[['station',
#          'London Liverpool Street',
#          51.51799,
#          -0.08143,
#          'GB',
#          'Europe/London'],
#         0,
#         0,
#         'False',
#         'False'],
#        [['station',
#          'Hackney Downs',
#          51.54876,
#          -0.06082,
#          'GB',
#          'Europe/London'],
#         6,
#         6,
#         'False',
#         'False'],
#        [['station',
#          'Tottenham Hale',
#          51.58831,
#          -0.05993,
#          'GB',
#          'Europe/London'],
#         12,
#         13,
#         'False',
#         'False']],
#       '',
#       [],
#       [],
#       [['London Liverpool Street - Hertford East', '', ''],
#        ['London Liverpool Street - Cheshunt', '', ''],
#        ['London Liverpool Street - Cambridge North', '', ''],
#        ['London Liverpool Street - Cambridge', '', ''],
#        ['London Liverpool Street - Bishops Stortford', '', ''],
#        ['London Liverpool Street - Ely', '', ''],
#        ['London Liverpool Street - Broxbourne', '', ''],
#        ['London Liverpool Street - Kings Lynn', '', '']],
#       [],
#       'Gtfs'],
#      ['Stansted Express',
#       '//static.r2r.io/logos/Trains/96/_STANSTED_EXPRESS_201906262235.png',
#       'https://www.stanstedexpress.com/',
#       'stanstedexpress.com',
#       660,
#       9.27837,
#       291,
#       'Stansted Express',
#       [['https://www.stanstedexpress.com/',
#         'Stansted Express',
#         'Website',
#         'Stansted Express',
#         '',
#         '',
#         '',
#         '',
#         '']],
#       [],
#       '0345 600 7245',
#       'customerrelations@abelliogreateranglia.co.uk',
#       '',
#       [['//static.r2r.io/transitimages/928866993.jpg', 483, 250],
#        ['//static.r2r.io/transitimages/1960661940.jpg', 483, 250],
#        ['//static.r2r.io/transitimages/1837516530.jpg', 400, 250],
#        ['//static.r2r.io/transitimages/776076613.jpg', 347, 250],
#        ['//static.r2r.io/transitimages/566245470.jpg', 373, 250],
#        ['//static.r2r.io/transitimages/1732707750.jpg', 428, 250],
#        ['//static.r2r.io/transitimages/1730958994.jpg', 373, 250],
#        ['//static.r2r.io/transitimages/1738560853.jpg', 376, 250]],
#       [],
#       [[12, 'USD', 12.6, 'False', ''],
#        [17, 'USD', 17.25, 'False', ''],
#        [20, 'USD', 19.15, 'False', '']],
#       [[10, 'GBP', 10.3, 'False', ''],
#        [14, 'GBP', 14.1, 'False', ''],
#        [16, 'GBP', 15.66, 'False', '']],
#       [['Standard',
#         [[13, 'USD', 12.6, 'False', ''],
#          [13, 'USD', 12.6, 'False', ''],
#          [13, 'USD', 12.6, 'False', '']]],
#        ['First',
#         [[20, 'USD', 19.15, 'False', ''],
#          [20, 'USD', 19.15, 'False', ''],
#          [20, 'USD', 19.15, 'False', '']]],
#        ['Business',
#         [[18, 'USD', 17.25, 'False', ''],
#          [18, 'USD', 17.25, 'False', ''],
#          [18, 'USD', 17.25, 'False', '']]]],
#       [['Standard',
#         [[11, 'GBP', 10.3, 'False', ''],
#          [11, 'GBP', 10.3, 'False', ''],
#          [11, 'GBP', 10.3, 'False', '']]],
#        ['First',
#         [[16, 'GBP', 15.66, 'False', ''],
#          [16, 'GBP', 15.66, 'False', ''],
#          [16, 'GBP', 15.66, 'False', '']]],
#        ['Business',
#         [[15, 'GBP', 14.1, 'False', ''],
#          [15, 'GBP', 14.1, 'False', ''],
#          [15, 'GBP', 14.1, 'False', '']]]],
#       '_STANSTED_EXPRESS',
#       ['station',
#        'London Liverpool Street',
#        51.51799,
#        -0.08143,
#        'GB',
#        'Europe/London'],
#       ['station', 'Tottenham Hale', 51.58831, -0.05993, 'GB', 'Europe/London'],
#       [[['station',
#          'London Liverpool Street',
#          51.51799,
#          -0.08143,
#          'GB',
#          'Europe/London'],
#         0,
#         0,
#         'False',
#         'False'],
#        [['station',
#          'Tottenham Hale',
#          51.58831,
#          -0.05993,
#          'GB',
#          'Europe/London'],
#         11,
#         12,
#         'False',
#         'False']],
#       '',
#       [],
#       [],
#       [['Stansted Express', '', '']],
#       [],
#       'Gtfs']]],
#    '',
#    'False',
#    [[3, 'USD', 3.7, 'False', ''],
#     [13, 'USD', 12.6, 'False', ''],
#     [20, 'USD', 19.15, 'False', '']],
#    [[3, 'GBP', 3.03, 'False', ''],
#     [10, 'GBP', 10.3, 'False', ''],
#     [16, 'GBP', 15.66, 'False', '']],
#    34,
#    34,
#    [],
#    [[['station',
#       'London Liverpool Street',
#       51.51799,
#       -0.08143,
#       'GB',
#       'Europe/London'],
#      0,
#      0,
#      'False',
#      'False'],
#     [['station', 'Hackney Downs', 51.54876, -0.06082, 'GB', 'Europe/London'],
#      6,
#      6,
#      'False',
#      'False'],
#     [['station', 'Tottenham Hale', 51.58831, -0.05993, 'GB', 'Europe/London'],
#      12,
#      13,
#      'False',
#      'False']],
#    [],
#    [],
#    '',
#    [],
#    ['_UK']],
#   ['walk',
#    'transfer',
#    'grey-walk',
#    0,
#    0,
#    0.07084133,
#    ['station', 'Tottenham Hale', 51.58831, -0.05993, 'GB', 'Europe/London'],
#    ['station',
#     'Tottenham Hale Bus Station',
#     51.58829,
#     -0.06098372,
#     'GB',
#     'Europe/London'],
#    '',
#    'False',
#    '',
#    '',
#    'True',
#    [['', '', ''], ['', '', ''], ['', '', '']],
#    [['', '', ''], ['', '', ''], ['', '', '']],
#    34,
#    34,
#    [],
#    [],
#    [],
#    [],
#    '',
#    '',
#    ['_UK']],
#   ['transit',
#    'busferry',
#    'orange',
#    140640,
#    3600,
#    2371.434,
#    ['station',
#     'Tottenham Hale Bus Station',
#     51.58829,
#     -0.06098372,
#     'GB',
#     'Europe/London'],
#    ['station', 'Cluj', 46.78374, 23.58729, 'RO', 'Europe/Bucharest'],
#    '',
#    'True',
#    [140640,
#     2371.434,
#     ['station',
#      'Tottenham Hale Bus Station',
#      51.58829,
#      -0.06098372,
#      'GB',
#      'Europe/London'],
#     ['station', 'Cluj', 46.78374, 23.58729, 'RO', 'Europe/Bucharest'],
#     'bus and ferry',
#     ['None'],
#     '',
#     1,
#     [['Iuga Class Lux',
#       '',
#       'https://iugaclasslux.ro/',
#       'iugaclasslux.ro',
#       140640,
#       2371.434,
#       1,
#       '',
#       [['https://iugaclasslux.ro/',
#         'iugaclasslux.ro',
#         'Schedules at',
#         'iugaclasslux.ro',
#         '',
#         '',
#         '',
#         '',
#         '']],
#       [],
#       '',
#       '',
#       '',
#       [],
#       [],
#       [[95, 'USD', 95.74, 'False', ''],
#        [110, 'USD', 109.79, 'False', ''],
#        [130, 'USD', 122.14, 'False', '']],
#       [[85, 'EUR', 88.29, 'False', ''],
#        [100, 'EUR', 101.25, 'False', ''],
#        [120, 'EUR', 112.64, 'False', '']],
#       [],
#       [],
#       '_IUGA_CLASS_LUX',
#       ['station',
#        'Tottenham Hale Bus Station',
#        51.58829,
#        -0.06098372,
#        'GB',
#        'Europe/London'],
#       ['station', 'Cluj', 46.78374, 23.58729, 'RO', 'Europe/Bucharest'],
#       [[['station',
#          'Tottenham Hale Bus Station',
#          51.58829,
#          -0.06098372,
#          'GB',
#          'Europe/London'],
#         '',
#         274,
#         'True',
#         'False'],
#        [['station', 'Barking', 51.53809, 0.07691306, 'GB', 'Europe/London'],
#         '',
#         287,
#         'True',
#         'False'],
#        [['station', 'Dagenham', 51.54116, 0.1480667, 'GB', 'Europe/London'],
#         '',
#         293,
#         'True',
#         'False'],
#        [['station',
#          'Chequers Bus Station',
#          51.27231,
#          0.5265915,
#          'GB',
#          'Europe/London'],
#         '',
#         341,
#         'True',
#         'False'],
#        [['station', 'Arad', 46.18996, 21.32616, 'RO', 'Europe/Bucharest'],
#         2285,
#         '',
#         'False',
#         'True'],
#        [['station', 'Deva', 45.88442, 22.91095, 'RO', 'Europe/Bucharest'],
#         2438,
#         '',
#         'False',
#         'True'],
#        [['station', 'Sebes', 45.95807, 23.57914, 'RO', 'Europe/Bucharest'],
#         2500,
#         '',
#         'False',
#         'True'],
#        [['station',
#          'Alba Iulia',
#          46.06004,
#          23.57686,
#          'RO',
#          'Europe/Bucharest'],
#         2514,
#         '',
#         'False',
#         'True'],
#        [['station', 'Turda', 46.56494, 23.77986, 'RO', 'Europe/Bucharest'],
#         2584,
#         '',
#         'False',
#         'True'],
#        [['station', 'Cluj', 46.78374, 23.58729, 'RO', 'Europe/Bucharest'],
#         2618,
#         '',
#         'False',
#         'True']],
#       '',
#       ['http://addlink.rome2rio.com/addlink2/?edit=EU\\Romania.busferry.Birlad - Cardiff.20140703.132459.R000984.json'],
#       [11],
#       [['', '', '']],
#       [],
#       'Addlink']]],
#    '',
#    'False',
#    [[95, 'USD', 95.74, 'False', ''],
#     [110, 'USD', 109.79, 'False', ''],
#     [130, 'USD', 122.14, 'False', '']],
#    [[85, 'EUR', 88.29, 'False', ''],
#     [100, 'EUR', 101.25, 'False', ''],
#     [120, 'EUR', 112.64, 'False', '']],
#    34,
#    53,
#    [],
#    [[['station',
#       'Tottenham Hale Bus Station',
#       51.58829,
#       -0.06098372,
#       'GB',
#       'Europe/London'],
#      '',
#      274,
#      'True',
#      'False'],
#     [['station', 'Barking', 51.53809, 0.07691306, 'GB', 'Europe/London'],
#      '',
#      287,
#      'True',
#      'False'],
#     [['station', 'Dagenham', 51.54116, 0.1480667, 'GB', 'Europe/London'],
#      '',
#      293,
#      'True',
#      'False'],
#     [['station',
#       'Chequers Bus Station',
#       51.27231,
#       0.5265915,
#       'GB',
#       'Europe/London'],
#      '',
#      341,
#      'True',
#      'False'],
#     [['station', 'Arad', 46.18996, 21.32616, 'RO', 'Europe/Bucharest'],
#      2285,
#      '',
#      'False',
#      'True'],
#     [['station', 'Deva', 45.88442, 22.91095, 'RO', 'Europe/Bucharest'],
#      2438,
#      '',
#      'False',
#      'True'],
#     [['station', 'Sebes', 45.95807, 23.57914, 'RO', 'Europe/Bucharest'],
#      2500,
#      '',
#      'False',
#      'True'],
#     [['station', 'Alba Iulia', 46.06004, 23.57686, 'RO', 'Europe/Bucharest'],
#      2514,
#      '',
#      'False',
#      'True'],
#     [['station', 'Turda', 46.56494, 23.77986, 'RO', 'Europe/Bucharest'],
#      2584,
#      '',
#      'False',
#      'True'],
#     [['station', 'Cluj', 46.78374, 23.58729, 'RO', 'Europe/Bucharest'],
#      2618,
#      '',
#      'False',
#      'True']],
#    [],
#    [],
#    '',
#    [],
#    []],
#   ['hotel',
#    ['station', 'Cluj-Napoca', 46.78634, 23.5807, 'RO', 'Europe/Bucharest'],
#    ['node', '', 46.77634, 23.5707],
#    ['node', '', 46.79634, 23.5907],
#    'BookingCom',
#    'BookingCom',
#    'https://www.booking.com/searchresults.en.html?aid=2097750&city=-1156174&lang=en&selected_currency=USD&label=r2r06,RUXXX20230116000000000usod,{{analyticsLabel}},,,202301160000,165-20230116-082928-6522487,']],
#  [[0,
#    1,
#    [0,
#     ['station', 'London Liverpool Street', 51.51799, -0.08143, '', '', -1],
#     ['station',
#      'Tottenham Hale Bus Station',
#      51.58829,
#      -0.06098372,
#      '',
#      '',
#      -1],
#     '',
#     '',
#     927.478,
#     927.478,
#     0,
#     [['car',
#       'taxi',
#       'yellow',
#       927.478,
#       0,
#       9.045202,
#       ['station',
#        'London Liverpool Street',
#        51.51799,
#        -0.08143,
#        'GB',
#        'Europe/London'],
#       ['station',
#        'Tottenham Hale Bus Station',
#        51.58829,
#        -0.06098372,
#        'GB',
#        'Europe/London'],
#       '',
#       'True',
#       '',
#       '',
#       'True',
#       [[35, 'USD', 36.51, 'False', ''],
#        [45, 'USD', 43.15, 'False', ''],
#        [45, 'USD', 43.15, 'False', '']],
#       [[29, 'GBP', 29.85, 'False', ''],
#        [35, 'GBP', 35.28, 'False', ''],
#        [40, 'GBP', 35.28, 'False', '']],
#       34,
#       34,
#       [['Gipsy Hill Cabs Airport Transfers',
#         '+44 20 8659 9999',
#         'https://www.gipsyhillminicabs.co.uk/',
#         'gipsyhillminicabs.co.uk'],
#        ['One-Number Taxi',
#         '+44 871 871 8710',
#         'http://www.the-london-taxi.com/',
#         'the-london-taxi.com'],
#        ['London Black Taxi',
#         '+44 020 3773 1948',
#         'https://www.theblacktaxilondon.com/#fh5co-home',
#         'theblacktaxilondon.com'],
#        ['Licenced London Taxi',
#         '+44 20 3633 1777',
#         'https://licensedlondontaxi.co.uk/',
#         'licensedlondontaxi.co.uk'],
#        ['Corporate Black Cabs',
#         '+44 7846 574174',
#         'https://corporateblackcabs.co.uk/',
#         'corporateblackcabs.co.uk'],
#        ['Minicabs North London',
#         '+44 208 226 5472',
#         'https://minicabsnorthlondon.co.uk/',
#         'minicabsnorthlondon.co.uk']],
#       [],
#       [],
#       [],
#       '',
#       '',
#       []],
#      ['final',
#       ['station',
#        'Tottenham Hale Bus Station',
#        51.58829,
#        -0.06098372,
#        'GB',
#        'Europe/London'],
#       ['node', '', 51.57829, -0.07098372],
#       ['node', '', 51.59829, -0.05098372]]],
#     [],
#     [['station',
#       'London Liverpool Street',
#       51.51799,
#       -0.08143,
#       'GB',
#       'Europe/London'],
#      ['station',
#       'Tottenham Hale Bus Station',
#       51.58829,
#       -0.06098372,
#       'GB',
#       'Europe/London']],
#     'True',
#     'True',
#     [],
#     [],
#     [[], []],
#     0,
#     '',
#     'Taxi',
#     [],
#     [[35, 'USD', 36.51, 'False', ''],
#      [45, 'USD', 43.15, 'False', ''],
#      [45, 'USD', 43.15, 'False', '']],
#     'False',
#     'False',
#     '']]],
#  [['station',
#    'London Liverpool Street',
#    51.51799,
#    -0.08143,
#    'GB',
#    'Europe/London'],
#   ['station', 'Tottenham Hale', 51.58831, -0.05993, 'GB', 'Europe/London'],
#   ['station',
#    'Tottenham Hale Bus Station',
#    51.58829,
#    -0.06098372,
#    'GB',
#    'Europe/London'],
#   ['station', 'Cluj', 46.78374, 23.58729, 'RO', 'Europe/Bucharest']],
#  'True',
#  'True',
#  [],
#  [],
#  [[['OmioAtoc',
#     'Book at {0}',
#     'Omio',
#     'False',
#     'Schedules and Book',
#     [23,
#      8,
#      [[40, 'Adult', 'Adults', ''], [10, 'Child', 'Children', '']],
#      40,
#      [],
#      'True',
#      -1,
#      -1,
#      366,
#      'https://help.rome2rio.com/en/support/solutions/articles/22000239379-are-there-any-age-discounts-for-my-tickets-',
#      'False',
#      'False',
#      [],
#      'False'],
#     'False',
#     2],
#    ['Local',
#     '',
#     '',
#     'False',
#     'Schedules',
#     [5,
#      8,
#      [],
#      40,
#      [],
#      'False',
#      -1,
#      -1,
#      -1,
#      'https://help.rome2rio.com/en/support/solutions/articles/22000239379-are-there-any-age-discounts-for-my-tickets-',
#      'False',
#      'False',
#      [],
#      'False'],
#     'True',
#     19]],
#   [[[[0,
#       [[0, [0, 1]], [1, [0, 1]]],
#       [-1, []],
#       [-1, []],
#       ['/redirects/omio/?oDateTime={oDateTime}&iDateTime={iDateTime}&adults={adults}&seniors={seniors}&youths={youths}&ages={ages}&checkoutExitLabel={checkoutExitLabel}&originId=319636&destinationId=320483&mode=train&lang=en&currency=USD&requestId=165-20230116-082928-6522487&agencyIds=_NATIONAL_EXPRESS_EAST_ANGLIA',
#        'Omio',
#        'OmioSRP:train',
#        'London Liverpool Street',
#        'Tottenham Hale',
#        ['OmioAtoc', 'Local'],
#        0,
#        0]]]]]],
#  66145.235,
#  'NewAgenciesPolicy',
#  'BusOnFerry',
#  [],
#  [[99, 'USD', 98.7, 'False', ''],
#   [123, 'USD', 122.6, 'False', ''],
#   [149, 'USD', 149.15, 'False', '']],
#  'False',
#  'False',
#  '']

# %%
for path_id, path in enumerate(pathes):
    print(f'path # {path_id}\n')
    for i, route in enumerate(path[8][:-1]):
        for j, way in enumerate(route):
            print(path_id, '\t', i, '\t', j, '\t', way, '\n')
# Out:
# path # 0
#
# 0 	 0 	 0 	 transit
#
# 0 	 0 	 1 	 train
#
# 0 	 0 	 2 	 purple
#
# 0 	 0 	 3 	 660
#
# 0 	 0 	 4 	 1862.581
#
# 0 	 0 	 5 	 19.45039
#
# 0 	 0 	 6 	 ['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin']
#
# 0 	 0 	 7 	 ['station', 'Aix En Provence Tgv', 43.455, 5.31722, 'FR', 'Europe/Berlin']
#
# 0 	 0 	 8
#
# 0 	 0 	 9 	 False
#
# 0 	 0 	 10 	 [660, 19.45039, ['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin'], ['station', 'Aix En Provence Tgv', 43.455, 5.31722, 'FR', 'Europe/Berlin'], 'train', ['Commuter', ' Bicycles', ' Wheelchair'], 'Tgv', 113, [['TGV inOui', '//static.r2r.io/logos/Trains/96/_TGV_201809191230.png', 'https://en.oui.sncf/en/tgv', 'en.oui.sncf', 660, 19.45039, 99, 'Tgv', [['https://en.oui.sncf/en/', 'Oui.SNCF', 'Website', 'Oui.SNCF', '', '', '', '', '']], [], '0033 892 353535', '', '', [['//static.r2r.io/transitimages/860263293.jpg', 250, 250], ['//static.r2r.io/transitimages/471401388.jpg', 333, 250], ['//static.r2r.io/transitimages/785226804.jpg', 376, 250], ['//static.r2r.io/transitimages/98233786.jpg', 333, 250], ['//static.r2r.io/transitimages/1286142994.jpg', 333, 250]], [[['Tgv'], [1, 0, 1, 0], []]], [[14, 'EUR', 14.07, 'False', ''], [22, 'EUR', 21.95, 'False', ''], [25, 'EUR', 24.95, 'False', '']], [['', '', ''], ['', '', ''], ['', '', '']], [['2nd Class', [[21, 'EUR', 21.95, 'False', ''], [24, 'EUR', 23.53, 'False', ''], [25, 'EUR', 24.95, 'False', '']]], ['1st Class', [[14, 'EUR', 14.07, 'False', ''], [15, 'EUR', 15.2, 'False', ''], [17, 'EUR', 16.23, 'False', '']]]], [], '_TGV', ['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin'], ['station', 'Aix En Provence Tgv', 43.455, 5.31722, 'FR', 'Europe/Berlin'], [[['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin'], 0, 0, 'False', 'False'], [['station', 'Aix En Provence Tgv', 43.455, 5.31722, 'FR', 'Europe/Berlin'], 11, 14, 'False', 'False']], '', [], [], [['TGV', '', '']], [], 'Gtfs'], ['Swiss Railways (SBB/CFF/FFS)', '//static.r2r.io/logos/Trains/96/_SWISS_RAILWAYS_SBBCFFFFS_201901160119.png', 'https://www.sbb.ch/de', 'sbb.ch', 660, 19.18223, 54, 'Tgv', [['https://www.sbb.ch/en/home.html', 'Swiss Railways (SBB/CFF/FFS)', 'Website', 'Swiss Railways (SBB/CFF/FFS)', '', '', '', '', '']], [], '+41 51 220 11 11', '', 'RailService', [['//static.r2r.io/transitimages/1548858010.jpg', 333, 250], ['//static.r2r.io/transitimages/849973788.jpg', 374, 250], ['//static.r2r.io/transitimages/1664111143.jpg', 408, 250], ['//static.r2r.io/transitimages/1286142994.jpg', 333, 250]], [], [[13, 'EUR', 13.37, 'False', ''], [24, 'EUR', 23.55, 'False', ''], [24, 'EUR', 23.55, 'False', '']], [[13, 'CHF', 13.38, 'False', ''], [24, 'CHF', 23.58, 'False', ''], [24, 'CHF', 23.58, 'False', '']], [], [], '_SWISS_RAILWAYS_(SBB/CFF/FFS)', ['station', 'Marseille-Saint-Charles', 43.30381, 5.38195, 'FR', 'Europe/Berlin'], ['station', 'Aix-en-Provence TGV', 43.45517, 5.317227, 'FR', 'Europe/Berlin'], [[['station', 'Marseille-Saint-Charles', 43.30381, 5.38195, 'FR', 'Europe/Berlin'], 153, 166, 'False', 'False'], [['station', 'Aix-en-Provence TGV', 43.45517, 5.317227, 'FR', 'Europe/Berlin'], 177, 180, 'False', 'False']], '', [], [], [['TGV', '', '']], [], 'Gtfs'], ['SNCF', '//static.r2r.io/logos/trains/fr.png', 'https://www.sncf.com/fr', 'sncf.com', 720, 19.18223, 7, '84', [['https://www.sncf-connect.com/en-en/', 'Oui.SNCF', 'Website', 'Oui.SNCF', '', '', '', '', '']], [], '+33 9 70 60 99 70', '', '', [['//static.r2r.io/transitimages/543052651.jpg', 333, 250], ['//static.r2r.io/transitimages/115008400.jpg', 375, 250], ['//static.r2r.io/transitimages/818045227.jpg', 333, 250], ['//static.r2r.io/transitimages/2050645411.jpg', 187, 250], ['//static.r2r.io/transitimages/442381545.jpg', 333, 250], ['//static.r2r.io/transitimages/1286142994.jpg', 333, 250]], [[['84'], [1, 0, 1, 0], []]], [[4, 'EUR', 4.46, 'False', ''], [10, 'EUR', 10.37, 'False', ''], [15, 'EUR', 14.7, 'False', '']], [['', '', ''], ['', '', ''], ['', '', '']], [['2nd Class', [[4, 'EUR', 4.46, 'False', ''], [5, 'EUR', 5.48, 'False', ''], [7, 'EUR', 6.3, 'False', '']]], ['Rail 1st Class', [[10, 'EUR', 10.37, 'False', ''], [13, 'EUR', 12.79, 'False', ''], [15, 'EUR', 14.7, 'False', '']]]], [], '_FRENCH_RAILWAYS_(SNCF)', ['station', 'Marseille-St-Charles', 43.30381, 5.38195, 'FR', 'Euro ...
#
# 0 	 0 	 11
#
# 0 	 0 	 12 	 False
#
# 0 	 0 	 13 	 [[4, 'EUR', 4.46, 'False', ''], [15, 'EUR', 14.7, 'False', ''], [25, 'EUR', 24.95, 'False', '']]
#
# 0 	 0 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 0 	 0 	 15 	 53
#
# 0 	 0 	 16 	 53
#
# 0 	 0 	 17 	 []
#
# 0 	 0 	 18 	 [[['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin'], 0, 0, 'False', 'False'], [['station', 'Aix En Provence Tgv', 43.455, 5.31722, 'FR', 'Europe/Berlin'], 11, 14, 'False', 'False']]
#
# 0 	 0 	 19 	 []
#
# 0 	 0 	 20 	 []
#
# 0 	 0 	 21
#
# 0 	 0 	 22 	 []
#
# 0 	 0 	 23 	 ['_FR5']
#
# 0 	 1 	 0 	 walk
#
# 0 	 1 	 1 	 transfer
#
# 0 	 1 	 2 	 grey-walk
#
# 0 	 1 	 3 	 0
#
# 0 	 1 	 4 	 0
#
# 0 	 1 	 5 	 0.09556505
#
# 0 	 1 	 6 	 ['station', 'Aix En Provence Tgv', 43.455, 5.31722, 'FR', 'Europe/Berlin']
#
# 0 	 1 	 7 	 ['station', 'Aix-en-Provence Gare TGV', 43.45547, 5.316226, 'FR', 'Europe/Paris']
#
# 0 	 1 	 8
#
# 0 	 1 	 9 	 False
#
# 0 	 1 	 10
#
# 0 	 1 	 11
#
# 0 	 1 	 12 	 False
#
# 0 	 1 	 13 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 0 	 1 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 0 	 1 	 15 	 53
#
# 0 	 1 	 16 	 53
#
# 0 	 1 	 17 	 []
#
# 0 	 1 	 18 	 []
#
# 0 	 1 	 19 	 []
#
# 0 	 1 	 20 	 []
#
# 0 	 1 	 21
#
# 0 	 1 	 22
#
# 0 	 1 	 23 	 ['_FR5']
#
# 0 	 2 	 0 	 transit
#
# 0 	 2 	 1 	 shuttle
#
# 0 	 2 	 2 	 red
#
# 0 	 2 	 3 	 900
#
# 0 	 2 	 4 	 3600
#
# 0 	 2 	 5 	 11.82229
#
# 0 	 2 	 6 	 ['station', 'Aix-en-Provence Gare TGV', 43.45547, 5.316226, 'FR', 'Europe/Paris']
#
# 0 	 2 	 7 	 ['station', 'Marseille Airport', 43.44063, 5.223171, 'FR', 'Europe/Paris']
#
# 0 	 2 	 8
#
# 0 	 2 	 9 	 False
#
# 0 	 2 	 10 	 [900, 11.82229, ['station', 'Aix-en-Provence Gare TGV', 43.45547, 5.316226, 'FR', 'Europe/Paris'], ['station', 'Marseille Airport', 43.44063, 5.223171, 'FR', 'Europe/Paris'], 'shuttle', ['None'], '', 34, [['Payan', '//static.r2r.io/logos/Trains/96/Payan.png', 'http://www.payan-voyages.com/', 'payan-voyages.com', 900, 11.82229, 34, '', [['https://www.payan-voyages.com/', 'payan-voyages.com', 'Schedules at', 'payan-voyages.com', '', '', '', '', '']], [], '', '', '', [], [], [[1, 'EUR', 1.61, 'False', ''], [2, 'EUR', 1.74, 'False', ''], [2, 'EUR', 1.87, 'False', '']], [['', '', ''], ['', '', ''], ['', '', '']], [], [], '_PAYAN', ['station', 'Aix-en-Provence Gare TGV', 43.45547, 5.316226, 'FR', 'Europe/Paris'], ['station', 'Marseille Airport', 43.44063, 5.223171, 'FR', 'Europe/Paris'], [[['station', 'Aix-en-Provence Gare TGV', 43.45547, 5.316226, 'FR', 'Europe/Paris'], '', 135, 'True', 'False'], [['station', 'Marseille Airport', 43.44063, 5.223171, 'FR', 'Europe/Paris'], 150, 150, 'False', 'False']], '', ['http://addlink.rome2rio.com/addlink2/?edit=EU\\France.bus.Digne-les-Bains - Marseille Airport.20151216.205900.json'], [351], [['', '', '']], [], 'Addlink']]]
#
# 0 	 2 	 11
#
# 0 	 2 	 12 	 False
#
# 0 	 2 	 13 	 [[1, 'EUR', 1.61, 'False', ''], [2, 'EUR', 1.74, 'False', ''], [2, 'EUR', 1.87, 'False', '']]
#
# 0 	 2 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 0 	 2 	 15 	 53
#
# 0 	 2 	 16 	 53
#
# 0 	 2 	 17 	 []
#
# 0 	 2 	 18 	 [[['station', 'Aix-en-Provence Gare TGV', 43.45547, 5.316226, 'FR', 'Europe/Paris'], '', 135, 'True', 'False'], [['station', 'Marseille Airport', 43.44063, 5.223171, 'FR', 'Europe/Paris'], 150, 150, 'False', 'False']]
#
# 0 	 2 	 19 	 []
#
# 0 	 2 	 20 	 []
#
# 0 	 2 	 21
#
# 0 	 2 	 22 	 []
#
# 0 	 2 	 23 	 ['_FR5']
#
# 0 	 3 	 0 	 walk
#
# 0 	 3 	 1 	 transfer
#
# 0 	 3 	 2 	 grey-walk
#
# 0 	 3 	 3 	 0
#
# 0 	 3 	 4 	 0
#
# 0 	 3 	 5 	 0.19171
#
# 0 	 3 	 6 	 ['station', 'Marseille Airport', 43.44063, 5.223171, 'FR', 'Europe/Paris']
#
# 0 	 3 	 7 	 ['airport', 'Marseille (MRS)', 43.44105, 5.220867]
#
# 0 	 3 	 8
#
# 0 	 3 	 9 	 False
#
# 0 	 3 	 10
#
# 0 	 3 	 11
#
# 0 	 3 	 12 	 False
#
# 0 	 3 	 13 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 0 	 3 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 0 	 3 	 15 	 53
#
# 0 	 3 	 16 	 53
#
# 0 	 3 	 17 	 []
#
# 0 	 3 	 18 	 []
#
# 0 	 3 	 19 	 []
#
# 0 	 3 	 20 	 []
#
# 0 	 3 	 21
#
# 0 	 3 	 22
#
# 0 	 3 	 23 	 ['_FR5']
#
# 0 	 4 	 0 	 flight
#
# 0 	 4 	 1 	 turquoise
#
# 0 	 4 	 2 	 ['MRS', 'Marseille', '', 43.44105, 5.220867, "Provence-Alpes-Côte d'Azur", 'France', 'EU', '89 to 121 flights daily', 726]
#
# 0 	 4 	 3 	 ['TIV', 'Tivat', '', 42.41225, 18.71807, 'Tivat', 'Montenegro', 'EU', '8 to 14 flights daily', 77]
#
# 0 	 4 	 4 	 17100
#
# 0 	 4 	 5 	 17100
#
# 0 	 4 	 6 	 7200
#
# 0 	 4 	 7 	 5
#
# 0 	 4 	 8 	 Flights on Mon Thu Sat Sun
#
# 0 	 4 	 9 	 [2, 1, 0, 0, 1, 0, 1]
#
# 0 	 4 	 10 	 True
#
# 0 	 4 	 11 	 [[40, 'EUR', 41.99, 'False', ''], [130, 'EUR', 133.58, 'False', ''], [270, 'EUR', 263.09, 'False', '']]
#
# 0 	 4 	 12 	 [['BEG', 'Belgrade', '', 44.82037, 20.29233, 'RS-00', 'Serbia', 'EU', '70 to 101 flights daily', 593]]
#
# 0 	 4 	 13 	 []
#
# 0 	 4 	 14 	 ['/tickets/Marseille-(MRS)(43.44105,5.220867)/Tivat-(TIV)(42.41225,18.71807)?oDateTime={oDateTime}&iDateTime={iDateTime}&adults={adults}&seniors={seniors}&youths={youths}&ages={ages}&checkoutExitLabel={checkoutExitLabel}&mode=plane&requestId=232-20230116-105713-4023752', 'Tickets', 'Tickets:plane', 'Marseille-(MRS)(43.44105,5.220867)', 'Tivat-(TIV)(42.41225,18.71807)', [], 0, 0]
#
# 0 	 5 	 0 	 car
#
# 0 	 5 	 1 	 taxi
#
# 0 	 5 	 2 	 yellow
#
# 0 	 5 	 3 	 251.463
#
# 0 	 5 	 4 	 0
#
# 0 	 5 	 5 	 2.981035
#
# 0 	 5 	 6 	 ['airport', 'Tivat (TIV)', 42.41225, 18.71807]
#
# 0 	 5 	 7 	 ['node', 'Tivat', 42.42888, 18.70009, 'ME', 'Europe/Podgorica', 0.5]
#
# 0 	 5 	 8
#
# 0 	 5 	 9 	 False
#
# 0 	 5 	 10
#
# 0 	 5 	 11
#
# 0 	 5 	 12 	 False
#
# 0 	 5 	 13 	 [[2, 'EUR', 2.19, 'False', ''], [3, 'EUR', 2.59, 'False', ''], [3, 'EUR', 2.59, 'False', '']]
#
# 0 	 5 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 0 	 5 	 15 	 53
#
# 0 	 5 	 16 	 53
#
# 0 	 5 	 17 	 [['Red Taxi', '+382 67 254 800', 'http://www.redtaxikotor.com/', 'redtaxikotor.com'], ['Red Taxi', '+382 67 248 588', 'http://www.redtaxikotor.com/', 'redtaxikotor.com']]
#
# 0 	 5 	 18 	 []
#
# 0 	 5 	 19 	 []
#
# 0 	 5 	 20 	 []
#
# 0 	 5 	 21
#
# 0 	 5 	 22
#
# 0 	 5 	 23 	 []
#
# path # 1
#
# 1 	 0 	 0 	 transit
#
# 1 	 0 	 1 	 train
#
# 1 	 0 	 2 	 purple
#
# 1 	 0 	 3 	 5220
#
# 1 	 0 	 4 	 3600
#
# 1 	 0 	 5 	 308.6429
#
# 1 	 0 	 6 	 ['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin']
#
# 1 	 0 	 7 	 ['station', 'Lyon-Saint Exupery Tgv', 45.72083, 5.07556, 'FR', 'Europe/Berlin']
#
# 1 	 0 	 8
#
# 1 	 0 	 9 	 True
#
# 1 	 0 	 10 	 [5220, 308.6429, ['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin'], ['station', 'Lyon-Saint Exupery Tgv', 45.72083, 5.07556, 'FR', 'Europe/Berlin'], 'train', ['Bicycles', ' Wheelchair'], '7842', 35, [['SNCF', '//static.r2r.io/logos/trains/fr.png', 'https://www.sncf.com/fr', 'sncf.com', 5220, 308.6429, 35, '7820, 7832, 7836, 7838, 7842', [['https://www.sncf-connect.com/en-en/', 'Oui.SNCF', 'Website', 'Oui.SNCF', '', '', '', '', '']], [], '+33 9 70 60 99 70', '', '', [['//static.r2r.io/transitimages/543052651.jpg', 333, 250], ['//static.r2r.io/transitimages/115008400.jpg', 375, 250], ['//static.r2r.io/transitimages/818045227.jpg', 333, 250], ['//static.r2r.io/transitimages/2050645411.jpg', 187, 250], ['//static.r2r.io/transitimages/442381545.jpg', 333, 250], ['//static.r2r.io/transitimages/1286142994.jpg', 333, 250], ['//static.r2r.io/transitimages/1208961714.jpg', 473, 250]], [[['7820', '7832', '7836', '7838', '7842'], [1, 0, 1, 0], []]], [[35, 'EUR', 36.88, 'False', ''], [50, 'EUR', 52.11, 'False', ''], [75, 'EUR', 71.33, 'False', '']], [['', '', ''], ['', '', ''], ['', '', '']], [['2nd Class', [[35, 'EUR', 36.88, 'False', ''], [45, 'EUR', 45.33, 'False', ''], [55, 'EUR', 52.11, 'False', '']]], ['Rail 1st Class', [[50, 'EUR', 50.31, 'False', ''], [60, 'EUR', 62.04, 'False', ''], [75, 'EUR', 71.33, 'False', '']]]], [], '_FRENCH_RAILWAYS_(SNCF)', ['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin'], ['station', 'Lyon-Saint Exupery Tgv', 45.72083, 5.07556, 'FR', 'Europe/Berlin'], [[['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin'], 0, 0, 'False', 'False'], [['station', 'Aix En Provence Tgv', 43.455, 5.31722, 'FR', 'Europe/Berlin'], '', 15, 'True', 'False'], [['station', 'Avignon Tgv', 43.92167, 4.78556, 'FR', 'Europe/Berlin'], 34, 37, 'False', 'False'], [['station', 'Lyon-Saint Exupery Tgv', 45.72083, 5.07556, 'FR', 'Europe/Berlin'], 87, 91, 'False', 'False']], '', [], [], [['7842', '', ''], ['7820', '', ''], ['7838', '', ''], ['7836', '', ''], ['7832', '', '']], ['_SNCF'], 'Gtfs'], ['TGV inOui', '//static.r2r.io/logos/Trains/96/_TGV_201809191230.png', 'https://en.oui.sncf/en/tgv', 'en.oui.sncf', 5400, 308.6429, 2, 'Tgv', [['https://en.oui.sncf/en/', 'Oui.SNCF', 'Website', 'Oui.SNCF', '', '', '', '', '']], [], '0033 892 353535', '', '', [['//static.r2r.io/transitimages/860263293.jpg', 250, 250], ['//static.r2r.io/transitimages/471401388.jpg', 333, 250], ['//static.r2r.io/transitimages/785226804.jpg', 376, 250], ['//static.r2r.io/transitimages/98233786.jpg', 333, 250], ['//static.r2r.io/transitimages/1286142994.jpg', 333, 250], ['//static.r2r.io/transitimages/1208961714.jpg', 473, 250]], [[['Tgv'], [1, 0, 1, 0], []]], [[55, 'EUR', 57.84, 'False', ''], [65, 'EUR', 64.56, 'False', ''], [70, 'EUR', 68.95, 'False', '']], [['', '', ''], ['', '', ''], ['', '', '']], [['2nd Class', [[55, 'EUR', 57.84, 'False', ''], [60, 'EUR', 62, 'False', ''], [70, 'EUR', 65.76, 'False', '']]], ['1st Class', [[60, 'EUR', 59.76, 'False', ''], [65, 'EUR', 64.56, 'False', ''], [70, 'EUR', 68.95, 'False', '']]]], [], '_TGV', ['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin'], ['station', 'Lyon-Saint Exupery Tgv', 45.72083, 5.07556, 'FR', 'Europe/Berlin'], [[['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin'], 0, 0, 'False', 'False'], [['station', 'Aix En Provence Tgv', 43.455, 5.31722, 'FR', 'Europe/Berlin'], 11, 14, 'False', 'False'], [['station', 'Avignon Tgv', 43.92167, 4.78556, 'FR', 'Europe/Berlin'], 34, 37, 'False', 'False'], [['station', 'Lyon-Saint Exupery Tgv', 45.72083, 5.07556, 'FR', 'Europe/Berlin'], 90, 96, 'False', 'False']], '', [], [], [['TGV', '', '']], [], 'Gtfs']]]
#
# 1 	 0 	 11
#
# 1 	 0 	 12 	 False
#
# 1 	 0 	 13 	 [[35, 'EUR', 36.88, 'False', ''], [60, 'EUR', 62, 'False', ''], [75, 'EUR', 71.33, 'False', '']]
#
# 1 	 0 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 1 	 0 	 15 	 53
#
# 1 	 0 	 16 	 53
#
# 1 	 0 	 17 	 []
#
# 1 	 0 	 18 	 [[['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin'], 0, 0, 'False', 'False'], [['station', 'Aix En Provence Tgv', 43.455, 5.31722, 'FR', 'Europe/Berlin'], '', 15, 'True', 'False'], [['station', 'Avignon Tgv', 43.92167, 4.78556, 'FR', 'Europe/Berlin'], 34, 37, 'False', 'False'], [['station', 'Lyon-Saint Exupery Tgv', 45.72083, 5.07556, 'FR', 'Europe/Berlin'], 87, 91, 'False', 'False']]
#
# 1 	 0 	 19 	 []
#
# 1 	 0 	 20 	 []
#
# 1 	 0 	 21
#
# 1 	 0 	 22 	 []
#
# 1 	 0 	 23 	 ['_FR5']
#
# 1 	 1 	 0 	 walk
#
# 1 	 1 	 1 	 transfer
#
# 1 	 1 	 2 	 grey-walk
#
# 1 	 1 	 3 	 0
#
# 1 	 1 	 4 	 0
#
# 1 	 1 	 5 	 0.2083144
#
# 1 	 1 	 6 	 ['station', 'Lyon-Saint Exupery Tgv', 45.72083, 5.07556, 'FR', 'Europe/Berlin']
#
# 1 	 1 	 7 	 ['airport', 'Lyon (LYS)', 45.72071, 5.07824]
#
# 1 	 1 	 8
#
# 1 	 1 	 9 	 False
#
# 1 	 1 	 10
#
# 1 	 1 	 11
#
# 1 	 1 	 12 	 False
#
# 1 	 1 	 13 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 1 	 1 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 1 	 1 	 15 	 53
#
# 1 	 1 	 16 	 53
#
# 1 	 1 	 17 	 []
#
# 1 	 1 	 18 	 []
#
# 1 	 1 	 19 	 []
#
# 1 	 1 	 20 	 []
#
# 1 	 1 	 21
#
# 1 	 1 	 22
#
# 1 	 1 	 23 	 ['_FR5']
#
# 1 	 2 	 0 	 flight
#
# 1 	 2 	 1 	 turquoise
#
# 1 	 2 	 2 	 ['LYS', 'Lyon', '', 45.72071, 5.07824, 'Auvergne-Rhône-Alpes', 'France', 'EU', '90 to 120 flights daily', 723]
#
# 1 	 2 	 3 	 ['DBV', 'Dubrovnik', '', 42.5599, 18.26294, 'Dubrovačko-Neretvanska', 'Croatia', 'EU', '14 to 42 flights daily', 161]
#
# 1 	 2 	 4 	 6300
#
# 1 	 2 	 5 	 6300
#
# 1 	 2 	 6 	 7200
#
# 1 	 2 	 7 	 2
#
# 1 	 2 	 8 	 Flights on Tue Sat
#
# 1 	 2 	 9 	 [0, 0, 1, 0, 0, 0, 1]
#
# 1 	 2 	 10 	 True
#
# 1 	 2 	 11 	 [[60, 'EUR', 60.56, 'False', ''], [160, 'EUR', 162.4, 'False', ''], [290, 'EUR', 283.57, 'False', '']]
#
# 1 	 2 	 12 	 []
#
# 1 	 2 	 13 	 ['_DALMATIA']
#
# 1 	 2 	 14 	 ['/tickets/Lyon-(LYS)(45.72071,5.07824)/Dubrovnik-(DBV)(42.5599,18.26294)?oDateTime={oDateTime}&iDateTime={iDateTime}&adults={adults}&seniors={seniors}&youths={youths}&ages={ages}&checkoutExitLabel={checkoutExitLabel}&mode=plane&requestId=232-20230116-105713-4023752', 'Tickets', 'Tickets:plane', 'Lyon-(LYS)(45.72071,5.07824)', 'Dubrovnik-(DBV)(42.5599,18.26294)', [], 0, 0]
#
# 1 	 3 	 0 	 car
#
# 1 	 3 	 1 	 car
#
# 1 	 3 	 2 	 grey-darker
#
# 1 	 3 	 3 	 5451.818
#
# 1 	 3 	 4 	 0
#
# 1 	 3 	 5 	 81.02496
#
# 1 	 3 	 6 	 ['airport', 'Dubrovnik (DBV)', 42.5599, 18.26294]
#
# 1 	 3 	 7 	 ['node', 'Tivat', 42.42888, 18.70009, 'ME', 'Europe/Podgorica', 0.5]
#
# 1 	 3 	 8
#
# 1 	 3 	 9 	 False
#
# 1 	 3 	 10
#
# 1 	 3 	 11
#
# 1 	 3 	 12 	 False
#
# 1 	 3 	 13 	 [[12, 'EUR', 12.2, 'False', ''], [15, 'EUR', 14.91, 'False', ''], [18, 'EUR', 17.62, 'False', '']]
#
# 1 	 3 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 1 	 3 	 15 	 53
#
# 1 	 3 	 16 	 53
#
# 1 	 3 	 17 	 []
#
# 1 	 3 	 18 	 []
#
# 1 	 3 	 19 	 [['Small vehicle', [[13, 'EUR', 12.2, 'False', ''], [13, 'EUR', 12.2, 'False', ''], [13, 'EUR', 12.2, 'False', '']]], ['Medium vehicle', [[15, 'EUR', 14.91, 'False', ''], [15, 'EUR', 14.91, 'False', ''], [15, 'EUR', 14.91, 'False', '']]], ['Large vehicle', [[18, 'EUR', 17.62, 'False', ''], [18, 'EUR', 17.62, 'False', ''], [18, 'EUR', 17.62, 'False', '']]]]
#
# 1 	 3 	 20 	 []
#
# 1 	 3 	 21
#
# 1 	 3 	 22
#
# 1 	 3 	 23 	 []
#
# path # 2
#
# 2 	 0 	 0 	 transit
#
# 2 	 0 	 1 	 train
#
# 2 	 0 	 2 	 purple
#
# 2 	 0 	 3 	 660
#
# 2 	 0 	 4 	 1862.581
#
# 2 	 0 	 5 	 19.45039
#
# 2 	 0 	 6 	 ['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin']
#
# 2 	 0 	 7 	 ['station', 'Aix En Provence Tgv', 43.455, 5.31722, 'FR', 'Europe/Berlin']
#
# 2 	 0 	 8
#
# 2 	 0 	 9 	 False
#
# 2 	 0 	 10 	 [660, 19.45039, ['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin'], ['station', 'Aix En Provence Tgv', 43.455, 5.31722, 'FR', 'Europe/Berlin'], 'train', ['Commuter', ' Bicycles', ' Wheelchair'], 'Tgv', 113, [['TGV inOui', '//static.r2r.io/logos/Trains/96/_TGV_201809191230.png', 'https://en.oui.sncf/en/tgv', 'en.oui.sncf', 660, 19.45039, 99, 'Tgv', [['https://en.oui.sncf/en/', 'Oui.SNCF', 'Website', 'Oui.SNCF', '', '', '', '', '']], [], '0033 892 353535', '', '', [['//static.r2r.io/transitimages/860263293.jpg', 250, 250], ['//static.r2r.io/transitimages/471401388.jpg', 333, 250], ['//static.r2r.io/transitimages/785226804.jpg', 376, 250], ['//static.r2r.io/transitimages/98233786.jpg', 333, 250], ['//static.r2r.io/transitimages/1286142994.jpg', 333, 250]], [[['Tgv'], [1, 0, 1, 0], []]], [[14, 'EUR', 14.07, 'False', ''], [22, 'EUR', 21.95, 'False', ''], [25, 'EUR', 24.95, 'False', '']], [['', '', ''], ['', '', ''], ['', '', '']], [['2nd Class', [[21, 'EUR', 21.95, 'False', ''], [24, 'EUR', 23.53, 'False', ''], [25, 'EUR', 24.95, 'False', '']]], ['1st Class', [[14, 'EUR', 14.07, 'False', ''], [15, 'EUR', 15.2, 'False', ''], [17, 'EUR', 16.23, 'False', '']]]], [], '_TGV', ['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin'], ['station', 'Aix En Provence Tgv', 43.455, 5.31722, 'FR', 'Europe/Berlin'], [[['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin'], 0, 0, 'False', 'False'], [['station', 'Aix En Provence Tgv', 43.455, 5.31722, 'FR', 'Europe/Berlin'], 11, 14, 'False', 'False']], '', [], [], [['TGV', '', '']], [], 'Gtfs'], ['Swiss Railways (SBB/CFF/FFS)', '//static.r2r.io/logos/Trains/96/_SWISS_RAILWAYS_SBBCFFFFS_201901160119.png', 'https://www.sbb.ch/de', 'sbb.ch', 660, 19.18223, 54, 'Tgv', [['https://www.sbb.ch/en/home.html', 'Swiss Railways (SBB/CFF/FFS)', 'Website', 'Swiss Railways (SBB/CFF/FFS)', '', '', '', '', '']], [], '+41 51 220 11 11', '', 'RailService', [['//static.r2r.io/transitimages/1548858010.jpg', 333, 250], ['//static.r2r.io/transitimages/849973788.jpg', 374, 250], ['//static.r2r.io/transitimages/1664111143.jpg', 408, 250], ['//static.r2r.io/transitimages/1286142994.jpg', 333, 250]], [], [[13, 'EUR', 13.37, 'False', ''], [24, 'EUR', 23.55, 'False', ''], [24, 'EUR', 23.55, 'False', '']], [[13, 'CHF', 13.38, 'False', ''], [24, 'CHF', 23.58, 'False', ''], [24, 'CHF', 23.58, 'False', '']], [], [], '_SWISS_RAILWAYS_(SBB/CFF/FFS)', ['station', 'Marseille-Saint-Charles', 43.30381, 5.38195, 'FR', 'Europe/Berlin'], ['station', 'Aix-en-Provence TGV', 43.45517, 5.317227, 'FR', 'Europe/Berlin'], [[['station', 'Marseille-Saint-Charles', 43.30381, 5.38195, 'FR', 'Europe/Berlin'], 153, 166, 'False', 'False'], [['station', 'Aix-en-Provence TGV', 43.45517, 5.317227, 'FR', 'Europe/Berlin'], 177, 180, 'False', 'False']], '', [], [], [['TGV', '', '']], [], 'Gtfs'], ['SNCF', '//static.r2r.io/logos/trains/fr.png', 'https://www.sncf.com/fr', 'sncf.com', 720, 19.18223, 7, '84', [['https://www.sncf-connect.com/en-en/', 'Oui.SNCF', 'Website', 'Oui.SNCF', '', '', '', '', '']], [], '+33 9 70 60 99 70', '', '', [['//static.r2r.io/transitimages/543052651.jpg', 333, 250], ['//static.r2r.io/transitimages/115008400.jpg', 375, 250], ['//static.r2r.io/transitimages/818045227.jpg', 333, 250], ['//static.r2r.io/transitimages/2050645411.jpg', 187, 250], ['//static.r2r.io/transitimages/442381545.jpg', 333, 250], ['//static.r2r.io/transitimages/1286142994.jpg', 333, 250]], [[['84'], [1, 0, 1, 0], []]], [[4, 'EUR', 4.46, 'False', ''], [10, 'EUR', 10.37, 'False', ''], [15, 'EUR', 14.7, 'False', '']], [['', '', ''], ['', '', ''], ['', '', '']], [['2nd Class', [[4, 'EUR', 4.46, 'False', ''], [5, 'EUR', 5.48, 'False', ''], [7, 'EUR', 6.3, 'False', '']]], ['Rail 1st Class', [[10, 'EUR', 10.37, 'False', ''], [13, 'EUR', 12.79, 'False', ''], [15, 'EUR', 14.7, 'False', '']]]], [], '_FRENCH_RAILWAYS_(SNCF)', ['station', 'Marseille-St-Charles', 43.30381, 5.38195, 'FR', 'Euro ...
#
# 2 	 0 	 11
#
# 2 	 0 	 12 	 False
#
# 2 	 0 	 13 	 [[4, 'EUR', 4.46, 'False', ''], [15, 'EUR', 14.7, 'False', ''], [25, 'EUR', 24.95, 'False', '']]
#
# 2 	 0 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 2 	 0 	 15 	 53
#
# 2 	 0 	 16 	 53
#
# 2 	 0 	 17 	 []
#
# 2 	 0 	 18 	 [[['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin'], 0, 0, 'False', 'False'], [['station', 'Aix En Provence Tgv', 43.455, 5.31722, 'FR', 'Europe/Berlin'], 11, 14, 'False', 'False']]
#
# 2 	 0 	 19 	 []
#
# 2 	 0 	 20 	 []
#
# 2 	 0 	 21
#
# 2 	 0 	 22 	 []
#
# 2 	 0 	 23 	 ['_FR5']
#
# 2 	 1 	 0 	 walk
#
# 2 	 1 	 1 	 transfer
#
# 2 	 1 	 2 	 grey-walk
#
# 2 	 1 	 3 	 0
#
# 2 	 1 	 4 	 0
#
# 2 	 1 	 5 	 0.09556505
#
# 2 	 1 	 6 	 ['station', 'Aix En Provence Tgv', 43.455, 5.31722, 'FR', 'Europe/Berlin']
#
# 2 	 1 	 7 	 ['station', 'Aix-en-Provence Gare TGV', 43.45547, 5.316226, 'FR', 'Europe/Paris']
#
# 2 	 1 	 8
#
# 2 	 1 	 9 	 False
#
# 2 	 1 	 10
#
# 2 	 1 	 11
#
# 2 	 1 	 12 	 False
#
# 2 	 1 	 13 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 2 	 1 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 2 	 1 	 15 	 53
#
# 2 	 1 	 16 	 53
#
# 2 	 1 	 17 	 []
#
# 2 	 1 	 18 	 []
#
# 2 	 1 	 19 	 []
#
# 2 	 1 	 20 	 []
#
# 2 	 1 	 21
#
# 2 	 1 	 22
#
# 2 	 1 	 23 	 ['_FR5']
#
# 2 	 2 	 0 	 transit
#
# 2 	 2 	 1 	 shuttle
#
# 2 	 2 	 2 	 red
#
# 2 	 2 	 3 	 900
#
# 2 	 2 	 4 	 3600
#
# 2 	 2 	 5 	 11.82229
#
# 2 	 2 	 6 	 ['station', 'Aix-en-Provence Gare TGV', 43.45547, 5.316226, 'FR', 'Europe/Paris']
#
# 2 	 2 	 7 	 ['station', 'Marseille Airport', 43.44063, 5.223171, 'FR', 'Europe/Paris']
#
# 2 	 2 	 8
#
# 2 	 2 	 9 	 False
#
# 2 	 2 	 10 	 [900, 11.82229, ['station', 'Aix-en-Provence Gare TGV', 43.45547, 5.316226, 'FR', 'Europe/Paris'], ['station', 'Marseille Airport', 43.44063, 5.223171, 'FR', 'Europe/Paris'], 'shuttle', ['None'], '', 34, [['Payan', '//static.r2r.io/logos/Trains/96/Payan.png', 'http://www.payan-voyages.com/', 'payan-voyages.com', 900, 11.82229, 34, '', [['https://www.payan-voyages.com/', 'payan-voyages.com', 'Schedules at', 'payan-voyages.com', '', '', '', '', '']], [], '', '', '', [], [], [[1, 'EUR', 1.61, 'False', ''], [2, 'EUR', 1.74, 'False', ''], [2, 'EUR', 1.87, 'False', '']], [['', '', ''], ['', '', ''], ['', '', '']], [], [], '_PAYAN', ['station', 'Aix-en-Provence Gare TGV', 43.45547, 5.316226, 'FR', 'Europe/Paris'], ['station', 'Marseille Airport', 43.44063, 5.223171, 'FR', 'Europe/Paris'], [[['station', 'Aix-en-Provence Gare TGV', 43.45547, 5.316226, 'FR', 'Europe/Paris'], '', 135, 'True', 'False'], [['station', 'Marseille Airport', 43.44063, 5.223171, 'FR', 'Europe/Paris'], 150, 150, 'False', 'False']], '', ['http://addlink.rome2rio.com/addlink2/?edit=EU\\France.bus.Digne-les-Bains - Marseille Airport.20151216.205900.json'], [351], [['', '', '']], [], 'Addlink']]]
#
# 2 	 2 	 11
#
# 2 	 2 	 12 	 False
#
# 2 	 2 	 13 	 [[1, 'EUR', 1.61, 'False', ''], [2, 'EUR', 1.74, 'False', ''], [2, 'EUR', 1.87, 'False', '']]
#
# 2 	 2 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 2 	 2 	 15 	 53
#
# 2 	 2 	 16 	 53
#
# 2 	 2 	 17 	 []
#
# 2 	 2 	 18 	 [[['station', 'Aix-en-Provence Gare TGV', 43.45547, 5.316226, 'FR', 'Europe/Paris'], '', 135, 'True', 'False'], [['station', 'Marseille Airport', 43.44063, 5.223171, 'FR', 'Europe/Paris'], 150, 150, 'False', 'False']]
#
# 2 	 2 	 19 	 []
#
# 2 	 2 	 20 	 []
#
# 2 	 2 	 21
#
# 2 	 2 	 22 	 []
#
# 2 	 2 	 23 	 ['_FR5']
#
# 2 	 3 	 0 	 walk
#
# 2 	 3 	 1 	 transfer
#
# 2 	 3 	 2 	 grey-walk
#
# 2 	 3 	 3 	 0
#
# 2 	 3 	 4 	 0
#
# 2 	 3 	 5 	 0.19171
#
# 2 	 3 	 6 	 ['station', 'Marseille Airport', 43.44063, 5.223171, 'FR', 'Europe/Paris']
#
# 2 	 3 	 7 	 ['airport', 'Marseille (MRS)', 43.44105, 5.220867]
#
# 2 	 3 	 8
#
# 2 	 3 	 9 	 False
#
# 2 	 3 	 10
#
# 2 	 3 	 11
#
# 2 	 3 	 12 	 False
#
# 2 	 3 	 13 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 2 	 3 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 2 	 3 	 15 	 53
#
# 2 	 3 	 16 	 53
#
# 2 	 3 	 17 	 []
#
# 2 	 3 	 18 	 []
#
# 2 	 3 	 19 	 []
#
# 2 	 3 	 20 	 []
#
# 2 	 3 	 21
#
# 2 	 3 	 22
#
# 2 	 3 	 23 	 ['_FR5']
#
# 2 	 4 	 0 	 flight
#
# 2 	 4 	 1 	 turquoise
#
# 2 	 4 	 2 	 ['MRS', 'Marseille', '', 43.44105, 5.220867, "Provence-Alpes-Côte d'Azur", 'France', 'EU', '89 to 121 flights daily', 726]
#
# 2 	 4 	 3 	 ['TGD', 'Podgorica', '', 42.3672, 19.24603, 'Podgorica', 'Montenegro', 'EU', '16 to 23 flights daily', 132]
#
# 2 	 4 	 4 	 17100
#
# 2 	 4 	 5 	 17700
#
# 2 	 4 	 6 	 7200
#
# 2 	 4 	 7 	 17
#
# 2 	 4 	 8 	 1 to 5 flights daily
#
# 2 	 4 	 9 	 [3, 2, 1, 1, 3, 2, 5]
#
# 2 	 4 	 10 	 True
#
# 2 	 4 	 11 	 [[90, 'EUR', 93.33, 'False', ''], [190, 'EUR', 192.86, 'False', ''], [320, 'EUR', 316.28, 'False', '']]
#
# 2 	 4 	 12 	 [['BEG', 'Belgrade', '', 44.82037, 20.29233, 'RS-00', 'Serbia', 'EU', '70 to 101 flights daily', 593]]
#
# 2 	 4 	 13 	 []
#
# 2 	 4 	 14 	 ['/tickets/Marseille-(MRS)(43.44105,5.220867)/Podgorica-(TGD)(42.3672,19.24603)?oDateTime={oDateTime}&iDateTime={iDateTime}&adults={adults}&seniors={seniors}&youths={youths}&ages={ages}&checkoutExitLabel={checkoutExitLabel}&mode=plane&requestId=232-20230116-105713-4023752', 'Tickets', 'Tickets:plane', 'Marseille-(MRS)(43.44105,5.220867)', 'Podgorica-(TGD)(42.3672,19.24603)', [], 0, 0]
#
# 2 	 5 	 0 	 walk
#
# 2 	 5 	 1 	 walk
#
# 2 	 5 	 2 	 grey-walk
#
# 2 	 5 	 3 	 1222.405
#
# 2 	 5 	 4 	 0
#
# 2 	 5 	 5 	 1.697799
#
# 2 	 5 	 6 	 ['airport', 'Podgorica (TGD)', 42.3672, 19.24603]
#
# 2 	 5 	 7 	 ['station', 'Aerodrom', 42.36547, 19.23452, 'ME', 'Europe/Podgorica']
#
# 2 	 5 	 8
#
# 2 	 5 	 9 	 False
#
# 2 	 5 	 10
#
# 2 	 5 	 11
#
# 2 	 5 	 12 	 False
#
# 2 	 5 	 13 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 2 	 5 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 2 	 5 	 15 	 53
#
# 2 	 5 	 16 	 53
#
# 2 	 5 	 17 	 []
#
# 2 	 5 	 18 	 []
#
# 2 	 5 	 19 	 []
#
# 2 	 5 	 20 	 []
#
# 2 	 5 	 21
#
# 2 	 5 	 22
#
# 2 	 5 	 23 	 []
#
# 2 	 6 	 0 	 transit
#
# 2 	 6 	 1 	 train
#
# 2 	 6 	 2 	 purple
#
# 2 	 6 	 3 	 420
#
# 2 	 6 	 4 	 3600
#
# 2 	 6 	 5 	 8.766924
#
# 2 	 6 	 6 	 ['station', 'Aerodrom', 42.36547, 19.23452, 'ME', 'Europe/Podgorica']
#
# 2 	 6 	 7 	 ['station', 'Podgorica', 42.43247, 19.26945, 'ME', 'Europe/Podgorica']
#
# 2 	 6 	 8
#
# 2 	 6 	 9 	 False
#
# 2 	 6 	 10 	 [420, 8.766924, ['station', 'Aerodrom', 42.36547, 19.23452, 'ME', 'Europe/Podgorica'], ['station', 'Podgorica', 42.43247, 19.26945, 'ME', 'Europe/Podgorica'], 'train', ['None'], '', 63, [['Railways of Montenegro (ŽPCG)', '//static.r2r.io/logos/trains/me.png', 'http://www.zcg-prevoz.me', 'zcg-prevoz.me', 420, 8.766924, 63, '', [['http://www.zcg-prevoz.me/points-of-sale.html', 'zcg-prevoz.me', 'Website', 'zcg-prevoz.me', '', '', '', '', '']], [], '', '', '', [], [], [[1, 'EUR', 0.43, 'False', ''], [1, 'EUR', 0.68, 'False', ''], [2, 'EUR', 1.83, 'False', '']], [['', '', ''], ['', '', ''], ['', '', '']], [['Second Class', [[1, 'EUR', 0.43, 'False', ''], [1, 'EUR', 0.45, 'False', ''], [1, 'EUR', 0.47, 'False', '']]], ['First Class', [[1, 'EUR', 0.65, 'False', ''], [1, 'EUR', 0.68, 'False', ''], [1, 'EUR', 0.71, 'False', '']]]], [], '_RAILWAYS_OF_MONTENEGRO_(ŽPCG)', ['station', 'Aerodrom', 42.36547, 19.23452, 'ME', 'Europe/Podgorica'], ['station', 'Podgorica', 42.43247, 19.26945, 'ME', 'Europe/Podgorica'], [[['station', 'Aerodrom', 42.36547, 19.23452, 'ME', 'Europe/Podgorica'], 52, 53, 'False', 'False'], [['station', 'Podgorica', 42.43247, 19.26945, 'ME', 'Europe/Podgorica'], 60, 60, 'False', 'False']], '', ['http://addlink.rome2rio.com/addlink2/?edit=EU\\Montenegro.train.Zeljeznicka Stanica Bar - Podgorica (6158).20170929.085620.json', 'http://addlink.rome2rio.com/addlink2/?edit=EU\\Montenegro.train.Zeljeznicka Stanica Bar - Bijelo Polje (6100).20170929.081221.json'], [245, 254], [['', '', '']], [], 'Addlink']]]
#
# 2 	 6 	 11
#
# 2 	 6 	 12 	 False
#
# 2 	 6 	 13 	 [[1, 'EUR', 0.43, 'False', ''], [1, 'EUR', 0.68, 'False', ''], [2, 'EUR', 1.83, 'False', '']]
#
# 2 	 6 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 2 	 6 	 15 	 53
#
# 2 	 6 	 16 	 53
#
# 2 	 6 	 17 	 []
#
# 2 	 6 	 18 	 [[['station', 'Aerodrom', 42.36547, 19.23452, 'ME', 'Europe/Podgorica'], 52, 53, 'False', 'False'], [['station', 'Podgorica', 42.43247, 19.26945, 'ME', 'Europe/Podgorica'], 60, 60, 'False', 'False']]
#
# 2 	 6 	 19 	 [['Second Class', [[1, 'EUR', 0.43, 'False', ''], [1, 'EUR', 0.45, 'False', ''], [1, 'EUR', 0.47, 'False', '']]], ['First Class', [[1, 'EUR', 0.65, 'False', ''], [1, 'EUR', 0.68, 'False', ''], [1, 'EUR', 0.71, 'False', '']]]]
#
# 2 	 6 	 20 	 []
#
# 2 	 6 	 21
#
# 2 	 6 	 22 	 []
#
# 2 	 6 	 23 	 []
#
# 2 	 7 	 0 	 walk
#
# 2 	 7 	 1 	 transfer
#
# 2 	 7 	 2 	 grey-walk
#
# 2 	 7 	 3 	 0
#
# 2 	 7 	 4 	 0
#
# 2 	 7 	 5 	 0.1045277
#
# 2 	 7 	 6 	 ['station', 'Podgorica', 42.43247, 19.26945, 'ME', 'Europe/Podgorica']
#
# 2 	 7 	 7 	 ['station', 'Podgorica', 42.43232, 19.26819, 'ME', 'Europe/Podgorica']
#
# 2 	 7 	 8
#
# 2 	 7 	 9 	 False
#
# 2 	 7 	 10
#
# 2 	 7 	 11
#
# 2 	 7 	 12 	 False
#
# 2 	 7 	 13 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 2 	 7 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 2 	 7 	 15 	 53
#
# 2 	 7 	 16 	 53
#
# 2 	 7 	 17 	 []
#
# 2 	 7 	 18 	 []
#
# 2 	 7 	 19 	 []
#
# 2 	 7 	 20 	 []
#
# 2 	 7 	 21
#
# 2 	 7 	 22
#
# 2 	 7 	 23 	 []
#
# 2 	 8 	 0 	 transit
#
# 2 	 8 	 1 	 bus
#
# 2 	 8 	 2 	 orange
#
# 2 	 8 	 3 	 7320
#
# 2 	 8 	 4 	 3600
#
# 2 	 8 	 5 	 84.85532
#
# 2 	 8 	 6 	 ['station', 'Podgorica', 42.43232, 19.26819, 'ME', 'Europe/Podgorica']
#
# 2 	 8 	 7 	 ['station', 'Tivat', 42.4362, 18.69801, 'ME', 'Europe/Podgorica']
#
# 2 	 8 	 8
#
# 2 	 8 	 9 	 True
#
# 2 	 8 	 10 	 [7320, 84.85532, ['station', 'Podgorica', 42.43232, 19.26819, 'ME', 'Europe/Podgorica'], ['station', 'Tivat', 42.4362, 18.69801, 'ME', 'Europe/Podgorica'], 'bus', ['None'], '', 14, [['Gardasevic', '//static.r2r.io/logos/Trains/96/_GARDASEVIC_201904052037.png', 'https://www.polazak.rs/ci/Gardasevic/prevoznik/', 'polazak.rs', 7320, 84.85532, 14, '', [['https://www.polazak.rs/ci/Gardasevic/prevoznik/', 'polazak.rs', 'Schedules at', 'polazak.rs', '', '', '', '', '']], [], '040 214 382', 'gardasevic@t-com.me', '', [['//static.r2r.io/transitimages/1828758189.jpg', 374, 250], ['//static.r2r.io/transitimages/612185509.jpg', 737, 250], ['//static.r2r.io/transitimages/419387274.jpg', 737, 250], ['//static.r2r.io/transitimages/255698011.jpg', 333, 250]], [], [[4, 'EUR', 4.48, 'False', ''], [9, 'EUR', 9, 'False', ''], [9, 'EUR', 9, 'False', '']], [['', '', ''], ['', '', ''], ['', '', '']], [], [], '_GARDASEVIC', ['station', 'Podgorica', 42.43232, 19.26819, 'ME', 'Europe/Podgorica'], ['station', 'Tivat', 42.4362, 18.69801, 'ME', 'Europe/Podgorica'], [[['station', 'Podgorica', 42.43232, 19.26819, 'ME', 'Europe/Podgorica'], 63, 63, 'False', 'False'], [['station', 'Cetinje', 42.39101, 18.92691, 'ME', 'Europe/Podgorica'], 110, 110, 'False', 'False'], [['station', 'Budva', 42.29014, 18.83915, 'ME', 'Europe/Podgorica'], 155, 155, 'False', 'False'], [['station', 'Tivat', 42.4362, 18.69801, 'ME', 'Europe/Podgorica'], 185, 185, 'False', 'False']], '', ['http://addlink.rome2rio.com/addlink2/?edit=EU\\Montenegro.bus.Niksic - Igalo.20140226.102558.json'], [1713], [['', '', '']], [], 'Addlink']]]
#
# 2 	 8 	 11
#
# 2 	 8 	 12 	 False
#
# 2 	 8 	 13 	 [[4, 'EUR', 4.48, 'False', ''], [9, 'EUR', 9, 'False', ''], [9, 'EUR', 9, 'False', '']]
#
# 2 	 8 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 2 	 8 	 15 	 53
#
# 2 	 8 	 16 	 53
#
# 2 	 8 	 17 	 []
#
# 2 	 8 	 18 	 [[['station', 'Podgorica', 42.43232, 19.26819, 'ME', 'Europe/Podgorica'], 63, 63, 'False', 'False'], [['station', 'Cetinje', 42.39101, 18.92691, 'ME', 'Europe/Podgorica'], 110, 110, 'False', 'False'], [['station', 'Budva', 42.29014, 18.83915, 'ME', 'Europe/Podgorica'], 155, 155, 'False', 'False'], [['station', 'Tivat', 42.4362, 18.69801, 'ME', 'Europe/Podgorica'], 185, 185, 'False', 'False']]
#
# 2 	 8 	 19 	 []
#
# 2 	 8 	 20 	 []
#
# 2 	 8 	 21
#
# 2 	 8 	 22 	 []
#
# 2 	 8 	 23 	 []
#
# path # 3
#
# 3 	 0 	 0 	 transit
#
# 3 	 0 	 1 	 train
#
# 3 	 0 	 2 	 purple
#
# 3 	 0 	 3 	 16800
#
# 3 	 0 	 4 	 3600
#
# 3 	 0 	 5 	 709.9919
#
# 3 	 0 	 6 	 ['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin']
#
# 3 	 0 	 7 	 ['station', 'Mulhouse Ville', 47.7425, 7.34306, 'FR', 'Europe/Berlin']
#
# 3 	 0 	 8
#
# 3 	 0 	 9 	 True
#
# 3 	 0 	 10 	 [16800, 709.9919, ['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin'], ['station', 'Mulhouse Ville', 47.7425, 7.34306, 'FR', 'Europe/Berlin'], 'train', ['Commuter', ' Bicycles', ' Wheelchair'], 'Tgv', 40, [['TGV inOui', '//static.r2r.io/logos/Trains/96/_TGV_201809191230.png', 'https://en.oui.sncf/en/tgv', 'en.oui.sncf', 16800, 709.9919, 31, 'Tgv', [['https://en.oui.sncf/en/', 'Oui.SNCF', 'Website', 'Oui.SNCF', '', '', '', '', '']], [], '0033 892 353535', '', '', [['//static.r2r.io/transitimages/860263293.jpg', 250, 250], ['//static.r2r.io/transitimages/471401388.jpg', 333, 250], ['//static.r2r.io/transitimages/785226804.jpg', 376, 250], ['//static.r2r.io/transitimages/98233786.jpg', 333, 250], ['//static.r2r.io/transitimages/1286142994.jpg', 333, 250]], [[['Tgv'], [1, 0, 1, 0], []]], [[100, 'EUR', 107.64, 'False', ''], [120, 'EUR', 123.17, 'False', ''], [150, 'EUR', 142.12, 'False', '']], [['', '', ''], ['', '', ''], ['', '', '']], [['2nd Class', [[100, 'EUR', 107.64, 'False', ''], [120, 'EUR', 115.38, 'False', ''], [130, 'EUR', 122.39, 'False', '']]], ['1st Class', [[120, 'EUR', 123.17, 'False', ''], [130, 'EUR', 133.07, 'False', ''], [150, 'EUR', 142.12, 'False', '']]]], [], '_TGV', ['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin'], ['station', 'Mulhouse Ville', 47.7425, 7.34306, 'FR', 'Europe/Berlin'], [[['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin'], 0, 0, 'False', 'False'], [['station', 'Aix En Provence Tgv', 43.455, 5.31722, 'FR', 'Europe/Berlin'], 12, 15, 'False', 'False'], [['station', 'Avignon Tgv', 43.92167, 4.78556, 'FR', 'Europe/Berlin'], 34, 37, 'False', 'False'], [['station', 'Lyon Part Dieu', 45.76028, 4.85889, 'FR', 'Europe/Berlin'], 103, 113, 'False', 'False'], [['station', 'Chalon Sur Saone', 46.78167, 4.84333, 'FR', 'Europe/Berlin'], 172, 175, 'False', 'False'], [['station', 'Besancon-Franche Comte Tgv', 47.30756, 5.95268, 'FR', 'Europe/Berlin'], 229, 232, 'False', 'False'], [['station', 'Belfort-Montbeliard Tgv', 47.58556, 6.89778, 'FR', 'Europe/Berlin'], 253, 256, 'False', 'False'], [['station', 'Mulhouse Ville', 47.7425, 7.34306, 'FR', 'Europe/Berlin'], 280, 283, 'False', 'False']], '', [], [], [['TGV', '', '']], [], 'Gtfs'], ['Swiss Railways (SBB/CFF/FFS)', '//static.r2r.io/logos/Trains/96/_SWISS_RAILWAYS_SBBCFFFFS_201901160119.png', 'https://www.sbb.ch/de', 'sbb.ch', 18540, 715.3015, 21, 'Tgv', [['https://www.sbb.ch/en/home.html', 'Swiss Railways (SBB/CFF/FFS)', 'Website', 'Swiss Railways (SBB/CFF/FFS)', '', '', '', '', '']], [], '+41 51 220 11 11', '', 'RailService', [['//static.r2r.io/transitimages/1548858010.jpg', 333, 250], ['//static.r2r.io/transitimages/849973788.jpg', 374, 250], ['//static.r2r.io/transitimages/1664111143.jpg', 408, 250], ['//static.r2r.io/transitimages/1286142994.jpg', 333, 250]], [], [[200, 'EUR', 209.09, 'False', ''], [370, 'EUR', 366.36, 'False', ''], [370, 'EUR', 366.36, 'False', '']], [[200, 'CHF', 209.29, 'False', ''], [370, 'CHF', 366.71, 'False', ''], [370, 'CHF', 366.71, 'False', '']], [], [], '_SWISS_RAILWAYS_(SBB/CFF/FFS)', ['station', 'Marseille-Saint-Charles', 43.30381, 5.38195, 'FR', 'Europe/Berlin'], ['station', 'Mulhouse', 47.74195, 7.343045, 'FR', 'Europe/Berlin'], [[['station', 'Marseille-Saint-Charles', 43.30381, 5.38195, 'FR', 'Europe/Berlin'], 153, 166, 'False', 'False'], [['station', 'Aix-en-Provence TGV', 43.45517, 5.317227, 'FR', 'Europe/Berlin'], 177, 180, 'False', 'False'], [['station', 'Avignon TGV', 43.92194, 4.786044, 'FR', 'Europe/Berlin'], 200, 203, 'False', 'False'], [['station', 'Lyon Part Dieu', 45.76056, 4.859993, 'FR', 'Europe/Berlin'], 266, 272, 'False', 'False'], [['station', 'Mâcon', 46.30294, 4.824807, 'FR', 'Europe/Berlin'], 309, 312, 'False', 'False'], [['station', 'Chalon-sur-Saône', 46.78174, 4.843393, 'FR', 'Europe/Berlin'], 341, 344, 'False', 'False'], [['station', 'Beaune', 47.02301, 4.848836, 'FR', 'Europe/Berlin'], 363, 366, 'False', ' ...
#
# 3 	 0 	 11
#
# 3 	 0 	 12 	 False
#
# 3 	 0 	 13 	 [[80, 'EUR', 81.87, 'False', ''], [120, 'EUR', 122.39, 'False', ''], [170, 'EUR', 163.47, 'False', '']]
#
# 3 	 0 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 3 	 0 	 15 	 53
#
# 3 	 0 	 16 	 53
#
# 3 	 0 	 17 	 []
#
# 3 	 0 	 18 	 [[['station', 'Marseille St Charles', 43.30278, 5.38028, 'FR', 'Europe/Berlin'], 0, 0, 'False', 'False'], [['station', 'Aix En Provence Tgv', 43.455, 5.31722, 'FR', 'Europe/Berlin'], 12, 15, 'False', 'False'], [['station', 'Avignon Tgv', 43.92167, 4.78556, 'FR', 'Europe/Berlin'], 34, 37, 'False', 'False'], [['station', 'Lyon Part Dieu', 45.76028, 4.85889, 'FR', 'Europe/Berlin'], 103, 113, 'False', 'False'], [['station', 'Chalon Sur Saone', 46.78167, 4.84333, 'FR', 'Europe/Berlin'], 172, 175, 'False', 'False'], [['station', 'Besancon-Franche Comte Tgv', 47.30756, 5.95268, 'FR', 'Europe/Berlin'], 229, 232, 'False', 'False'], [['station', 'Belfort-Montbeliard Tgv', 47.58556, 6.89778, 'FR', 'Europe/Berlin'], 253, 256, 'False', 'False'], [['station', 'Mulhouse Ville', 47.7425, 7.34306, 'FR', 'Europe/Berlin'], 280, 283, 'False', 'False']]
#
# 3 	 0 	 19 	 []
#
# 3 	 0 	 20 	 []
#
# 3 	 0 	 21
#
# 3 	 0 	 22 	 []
#
# 3 	 0 	 23 	 ['_FR5']
#
# 3 	 1 	 0 	 transit
#
# 3 	 1 	 1 	 train
#
# 3 	 1 	 2 	 purple
#
# 3 	 1 	 3 	 1320
#
# 3 	 1 	 4 	 787.176
#
# 3 	 1 	 5 	 33.78758
#
# 3 	 1 	 6 	 ['station', 'Mulhouse Ville', 47.7425, 7.34306, 'FR', 'Europe/Berlin']
#
# 3 	 1 	 7 	 ['station', 'Basel Sbb', 47.5475, 7.58945, 'CH', 'Europe/Berlin']
#
# 3 	 1 	 8
#
# 3 	 1 	 9 	 False
#
# 3 	 1 	 10 	 [1320, 33.78758, ['station', 'Mulhouse Ville', 47.7425, 7.34306, 'FR', 'Europe/Berlin'], ['station', 'Basel Sbb', 47.5475, 7.58945, 'CH', 'Europe/Berlin'], 'train', ['Commuter', ' Bicycles', ' Wheelchair'], 'Ter', 223, [['SNCF', '//static.r2r.io/logos/trains/fr.png', 'https://www.sncf.com/fr', 'sncf.com', 1320, 33.78758, 320, 'Ter', [['https://www.sncf-connect.com/en-en/', 'Oui.SNCF', 'Website', 'Oui.SNCF', '', '', '', '', '']], [], '+33 9 70 60 99 70', '', '', [['//static.r2r.io/transitimages/543052651.jpg', 333, 250], ['//static.r2r.io/transitimages/115008400.jpg', 375, 250], ['//static.r2r.io/transitimages/818045227.jpg', 333, 250], ['//static.r2r.io/transitimages/2050645411.jpg', 187, 250], ['//static.r2r.io/transitimages/442381545.jpg', 333, 250]], [[['Ter'], [1, 0, 1, 0], []]], [[6, 'EUR', 6.07, 'False', ''], [12, 'EUR', 12.35, 'False', ''], [18, 'EUR', 17.51, 'False', '']], [['', '', ''], ['', '', ''], ['', '', '']], [['2nd Class', [[6, 'EUR', 6.07, 'False', ''], [7, 'EUR', 7.46, 'False', ''], [9, 'EUR', 8.57, 'False', '']]], ['Rail 1st Class', [[12, 'EUR', 12.35, 'False', ''], [15, 'EUR', 15.23, 'False', ''], [18, 'EUR', 17.51, 'False', '']]]], [], '_FRENCH_RAILWAYS_(SNCF)', ['station', 'Mulhouse Ville', 47.7425, 7.34306, 'FR', 'Europe/Berlin'], ['station', 'Basel Sbb', 47.5475, 7.58945, 'CH', 'Europe/Berlin'], [[['station', 'Mulhouse Ville', 47.7425, 7.34306, 'FR', 'Europe/Berlin'], 53, 55, 'False', 'False'], [['station', 'St Louis', 47.59055, 7.55583, 'FR', 'Europe/Berlin'], 67, 68, 'False', 'False'], [['station', 'Basel Sbb', 47.5475, 7.58945, 'CH', 'Europe/Berlin'], 77, 77, 'False', 'False']], '', [], [], [['TER', '', '']], ['_SNCF'], 'Gtfs'], ['Swiss Railways (SBB/CFF/FFS)', '//static.r2r.io/logos/Trains/96/_SWISS_RAILWAYS_SBBCFFFFS_201901160119.png', 'https://www.sbb.ch/de', 'sbb.ch', 1200, 33.85111, 43, 'Tgv', [['https://www.sbb.ch/en/home.html', 'Swiss Railways (SBB/CFF/FFS)', 'Website', 'Swiss Railways (SBB/CFF/FFS)', '', '', '', '', '']], [], '+41 51 220 11 11', '', 'RailService', [['//static.r2r.io/transitimages/1548858010.jpg', 333, 250], ['//static.r2r.io/transitimages/849973788.jpg', 374, 250], ['//static.r2r.io/transitimages/1664111143.jpg', 408, 250], ['//static.r2r.io/transitimages/300702188.jpg', 333, 250]], [], [[17, 'EUR', 17.43, 'False', ''], [30, 'EUR', 30.67, 'False', ''], [35, 'EUR', 30.67, 'False', '']], [[17, 'CHF', 17.45, 'False', ''], [30, 'CHF', 30.7, 'False', ''], [35, 'CHF', 30.7, 'False', '']], [], [], '_SWISS_RAILWAYS_(SBB/CFF/FFS)', ['station', 'Mulhouse', 47.74195, 7.343045, 'FR', 'Europe/Berlin'], ['station', 'Basel SBB', 47.54741, 7.589561, 'CH', 'Europe/Berlin'], [[['station', 'Mulhouse', 47.74195, 7.343045, 'FR', 'Europe/Berlin'], 0, 0, 'False', 'False'], [['station', 'Basel SBB', 47.54741, 7.589561, 'CH', 'Europe/Berlin'], 20, 27, 'False', 'False']], '', [], [], [['TGV', '', '']], [], 'Gtfs'], ['TGV inOui', '//static.r2r.io/logos/Trains/96/_TGV_201809191230.png', 'https://en.oui.sncf/en/tgv', 'en.oui.sncf', 1200, 33.78758, 21, 'Tgv', [['https://en.oui.sncf/en/', 'Oui.SNCF', 'Website', 'Oui.SNCF', '', '', '', '', '']], [], '0033 892 353535', '', '', [['//static.r2r.io/transitimages/860263293.jpg', 250, 250], ['//static.r2r.io/transitimages/471401388.jpg', 333, 250], ['//static.r2r.io/transitimages/785226804.jpg', 376, 250], ['//static.r2r.io/transitimages/98233786.jpg', 333, 250]], [[['Tgv'], [1, 0, 1, 0], []]], [[16, 'EUR', 16.33, 'False', ''], [24, 'EUR', 23.73, 'False', ''], [27, 'EUR', 26.98, 'False', '']], [['', '', ''], ['', '', ''], ['', '', '']], [['2nd Class', [[23, 'EUR', 23.73, 'False', ''], [25, 'EUR', 25.44, 'False', ''], [27, 'EUR', 26.98, 'False', '']]], ['1st Class', [[16, 'EUR', 16.33, 'False', ''], [18, 'EUR', 17.64, 'False', ''], [19, 'EUR', 18.85, 'False', '']]]], [], '_TGV', ['station', 'Mulhouse Ville', 47.7425, 7.34306, 'FR', 'Europe/Berlin'], ['station', 'Basel Sbb', 47.5475, 7.58945, 'CH', 'Europe/Berlin'], [[['station', 'Mulhouse Ville', 47.7 ...
#
# 3 	 1 	 11
#
# 3 	 1 	 12 	 False
#
# 3 	 1 	 13 	 [[6, 'EUR', 6.07, 'False', ''], [18, 'EUR', 17.51, 'False', ''], [27, 'EUR', 26.98, 'False', '']]
#
# 3 	 1 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 3 	 1 	 15 	 53
#
# 3 	 1 	 16 	 53
#
# 3 	 1 	 17 	 []
#
# 3 	 1 	 18 	 [[['station', 'Mulhouse Ville', 47.7425, 7.34306, 'FR', 'Europe/Berlin'], 53, 55, 'False', 'False'], [['station', 'St Louis', 47.59055, 7.55583, 'FR', 'Europe/Berlin'], 67, 68, 'False', 'False'], [['station', 'Basel Sbb', 47.5475, 7.58945, 'CH', 'Europe/Berlin'], 77, 77, 'False', 'False']]
#
# 3 	 1 	 19 	 []
#
# 3 	 1 	 20 	 []
#
# 3 	 1 	 21
#
# 3 	 1 	 22 	 []
#
# 3 	 1 	 23 	 []
#
# 3 	 2 	 0 	 walk
#
# 3 	 2 	 1 	 transfer
#
# 3 	 2 	 2 	 grey-walk
#
# 3 	 2 	 3 	 0
#
# 3 	 2 	 4 	 0
#
# 3 	 2 	 5 	 0.1559299
#
# 3 	 2 	 6 	 ['station', 'Basel Sbb', 47.5475, 7.58945, 'CH', 'Europe/Berlin']
#
# 3 	 2 	 7 	 ['station', 'Basel', 47.54611, 7.58917, 'CH', 'Europe/Zurich']
#
# 3 	 2 	 8
#
# 3 	 2 	 9 	 False
#
# 3 	 2 	 10
#
# 3 	 2 	 11
#
# 3 	 2 	 12 	 False
#
# 3 	 2 	 13 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 3 	 2 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 3 	 2 	 15 	 53
#
# 3 	 2 	 16 	 53
#
# 3 	 2 	 17 	 []
#
# 3 	 2 	 18 	 []
#
# 3 	 2 	 19 	 []
#
# 3 	 2 	 20 	 []
#
# 3 	 2 	 21
#
# 3 	 2 	 22
#
# 3 	 2 	 23 	 []
#
# 3 	 3 	 0 	 transit
#
# 3 	 3 	 1 	 bus
#
# 3 	 3 	 2 	 orange
#
# 3 	 3 	 3 	 57600
#
# 3 	 3 	 4 	 3600
#
# 3 	 3 	 5 	 1312.3
#
# 3 	 3 	 6 	 ['station', 'Basel', 47.54611, 7.58917, 'CH', 'Europe/Zurich']
#
# 3 	 3 	 7 	 ['station', 'Zvornik', 44.38512, 19.10509, 'BA', 'Europe/Sarajevo']
#
# 3 	 3 	 8
#
# 3 	 3 	 9 	 True
#
# 3 	 3 	 10 	 [57600, 1312.3, ['station', 'Basel', 47.54611, 7.58917, 'CH', 'Europe/Zurich'], ['station', 'Zvornik', 44.38512, 19.10509, 'BA', 'Europe/Sarajevo'], 'bus', ['None'], '', 2, [['Drina Trans', '//static.r2r.io/logos/Trains/96/Drinatrans.png', 'http://www.drinatrans.com', 'drinatrans.com', 57600, 1312.3, 2, '', [['http://www.drinatrans.com/medjunarodni/', 'drinatrans.com', 'Schedules at', 'drinatrans.com', '', '', '', '', '']], ['Please contact the operator for exact timetables.'], '+387 56 260-077', '', '', [['//static.r2r.io/transitimages/445079578.jpg', 314, 250], ['//static.r2r.io/transitimages/1186530039.jpg', 333, 250], ['//static.r2r.io/transitimages/1965952355.jpg', 333, 250], ['//static.r2r.io/transitimages/993979843.jpg', 332, 250]], [], [[60, 'EUR', 60.5, 'False', ''], [70, 'EUR', 70.86, 'False', ''], [80, 'EUR', 78.61, 'False', '']], [['', '', ''], ['', '', ''], ['', '', '']], [], [], '_DRINA_TRANS', ['station', 'Basel', 47.54611, 7.58917, 'CH', 'Europe/Zurich'], ['station', 'Zvornik', 44.38512, 19.10509, 'BA', 'Europe/Sarajevo'], [[['station', 'Basel', 47.54611, 7.58917, 'CH', 'Europe/Zurich'], 0, 0, 'False', 'False'], [['station', 'Zvornik', 44.38512, 19.10509, 'BA', 'Europe/Sarajevo'], 960, 960, 'False', 'False']], '', ['http://addlink.rome2rio.com/addlink2/?edit=EU\\Bosnia and Herzegovina.bus.Zvornik - Velenje.20180805.080131.json'], [30], [['', '', '']], [], 'Addlink']]]
#
# 3 	 3 	 11
#
# 3 	 3 	 12 	 False
#
# 3 	 3 	 13 	 [[60, 'EUR', 60.5, 'False', ''], [70, 'EUR', 70.86, 'False', ''], [80, 'EUR', 78.61, 'False', '']]
#
# 3 	 3 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 3 	 3 	 15 	 53
#
# 3 	 3 	 16 	 53
#
# 3 	 3 	 17 	 []
#
# 3 	 3 	 18 	 [[['station', 'Basel', 47.54611, 7.58917, 'CH', 'Europe/Zurich'], 0, 0, 'False', 'False'], [['station', 'Zvornik', 44.38512, 19.10509, 'BA', 'Europe/Sarajevo'], 960, 960, 'False', 'False']]
#
# 3 	 3 	 19 	 []
#
# 3 	 3 	 20 	 []
#
# 3 	 3 	 21
#
# 3 	 3 	 22 	 []
#
# 3 	 3 	 23 	 []
#
# 3 	 4 	 0 	 transit
#
# 3 	 4 	 1 	 bus
#
# 3 	 4 	 2 	 orange
#
# 3 	 4 	 3 	 16800
#
# 3 	 4 	 4 	 3600
#
# 3 	 4 	 5 	 350.2029
#
# 3 	 4 	 6 	 ['station', 'Zvornik', 44.38518, 19.10471, 'BA', 'Europe/Sarajevo']
#
# 3 	 4 	 7 	 ['station', 'Herceg Novi', 42.45308, 18.53383, 'ME', 'Europe/Podgorica']
#
# 3 	 4 	 8
#
# 3 	 4 	 9 	 True
#
# ...
#
# 4 	 1 	 15 	 53
#
# 4 	 1 	 16 	 53
#
# 4 	 1 	 17 	 []
#
# 4 	 1 	 18 	 []
#
# 4 	 1 	 19 	 []
#
# 4 	 1 	 20 	 []
#
# 4 	 1 	 21
#
# 4 	 1 	 22
#
# 4 	 1 	 23 	 []
#
# 4 	 2 	 0 	 transit
#
# 4 	 2 	 1 	 bus
#
# 4 	 2 	 2 	 orange
#
# 4 	 2 	 3 	 9900
#
# 4 	 2 	 4 	 3600
#
# 4 	 2 	 5 	 191.4595
#
# 4 	 2 	 6 	 ['station', 'Zagreb', 45.8038, 15.99288, 'HR', 'Europe/Zagreb']
#
# 4 	 2 	 7 	 ['station', 'Banja Luka', 44.78816, 17.21033, 'BA', 'Europe/Sarajevo']
#
# 4 	 2 	 8
#
# 4 	 2 	 9 	 True
#
# 4 	 2 	 10 	 [9900, 191.4595, ['station', 'Zagreb', 45.8038, 15.99288, 'HR', 'Europe/Zagreb'], ['station', 'Banja Luka', 44.78816, 17.21033, 'BA', 'Europe/Sarajevo'], 'bus', ['None'], '', 70, [['Pepeks Zagreb', '//static.r2r.io/logos/Trains/96/_PEPEKS_ZAGREB2016101969_20161019610.png', 'https://www.pepeks.hr/home/', 'pepeks.hr', 9900, 191.4595, 35, '', [['https://www.pepeks.hr/buy-tickets/zagreb-prijedor-en-us/', 'pepeks.hr', 'Schedules at', 'pepeks.hr', '', '', '', '', ''], ['https://www.pepeks.hr/buy-tickets/zagreb-prijedor-en-us/', 'pepeks.hr', 'Book at', 'pepeks.hr', '', '', '', '', '']], ['Operates in cooperation with Toping Trade d.o.o'], '098 417 140', 'info@pepeks.hr', '', [], [], [[23, 'EUR', 23, 'False', ''], [23, 'EUR', 23, 'False', ''], [23, 'EUR', 23, 'False', '']], [['', '', ''], ['', '', ''], ['', '', '']], [], [], '_PEPEKS_ZAGREB2016101969', ['station', 'Zagreb', 45.8038, 15.99288, 'HR', 'Europe/Zagreb'], ['station', 'Banja Luka', 44.78816, 17.21033, 'BA', 'Europe/Sarajevo'], [[['station', 'Zagreb', 45.8038, 15.99288, 'HR', 'Europe/Zagreb'], 0, 0, 'False', 'False'], [['station', 'Novska', 45.33979, 16.97857, 'HR', 'Europe/Zagreb'], '', 60, 'True', 'False'], [['station', 'Bosanski Gradiska Zob', 45.14368, 17.25487, 'BA', 'Europe/Sarajevo'], 110, '', 'False', 'True'], [['station', 'Nova Topola', 45.05266, 17.30811, 'BA', 'Europe/Sarajevo'], 135, '', 'False', 'True'], [['station', 'Laktasi', 44.90677, 17.30172, 'BA', 'Europe/Sarajevo'], 155, '', 'False', 'True'], [['station', 'Banja Luka', 44.78816, 17.21033, 'BA', 'Europe/Sarajevo'], 165, '', 'False', 'True']], '', ['http://addlink.rome2rio.com/addlink2/?edit=EU\\Croatia.bus.Zagreb - Prijedor.20161119.041456.json', 'http://addlink.rome2rio.com/addlink2/?edit=EU\\Croatia.bus.Zagreb - Novi Grad.20161119.043801.json', 'http://addlink.rome2rio.com/addlink2/?edit=EU\\Croatia.bus.Pula - Prijedor.20161119.041348.json', 'http://addlink.rome2rio.com/addlink2/?edit=EU\\Croatia.bus.Zagreb - Banja Luka.20161119.044131.json'], [158, 159, 163, 165], [['', '', '']], [], 'Addlink'], ['Croatia Bus International', '//static.r2r.io/logos/Trains/96/_CROATIA_BUS_201907240257.png', 'http://croatiabus.getbybus.com', 'croatiabus.getbybus.com', 12000, 180.7733, 21, '', [['https://croatiabus.getbybus.com/en/', 'croatiabus.getbybus.com', 'Schedules at', 'croatiabus.getbybus.com', '', '', '', '', ''], ['https://croatiabus.getbybus.com/en/', 'croatiabus.getbybus.com', 'Book at', 'croatiabus.getbybus.com', '', '', '', '', '']], [], '+385 1 6113 073', 'info@croatiabus.hr', '', [['//static.r2r.io/transitimages/391723238.jpg', 316, 250], ['//static.r2r.io/transitimages/1617777705.jpg', 425, 250], ['//static.r2r.io/transitimages/502575724.jpg', 333, 250], ['//static.r2r.io/transitimages/145989225.jpg', 333, 250]], [[[], [1, 1, 1, 0], ['Advance booking: <b>Recommended</b>.']]], [[18, 'EUR', 18.35, 'False', ''], [22, 'EUR', 22.09, 'False', ''], [26, 'EUR', 25.4, 'False', '']], [[130, 'HRK', 138.26, 'False', ''], [170, 'HRK', 166.42, 'False', ''], [200, 'HRK', 191.4, 'False', '']], [], [], '_CROATIA_BUS', ['station', 'Zagreb', 45.8038, 15.99288, 'HR', 'Europe/Zagreb'], ['station', 'Banja Luka', 44.78852, 17.21026, 'BA', 'Europe/Sarajevo'], [[['station', 'Zagreb', 45.8038, 15.99288, 'HR', 'Europe/Zagreb'], 0, 0, 'False', 'False'], [['station', 'Gradiška', 45.14379, 17.25428, 'BA', 'Europe/Sarajevo'], 142, '', 'False', 'True'], [['station', 'Nova Topola', 45.05038, 17.30786, 'BA', 'Europe/Sarajevo'], 155, '', 'False', 'True'], [['station', 'Laktaši', 44.90802, 17.30572, 'BA', 'Europe/Sarajevo'], 175, '', 'False', 'True'], [['station', 'Banja Luka', 44.78852, 17.21026, 'BA', 'Europe/Sarajevo'], 200, '', 'False', 'True']], '', ['http://addlink.rome2rio.com/addlink2/?edit=EU\\Croatia.bus.Zagreb - Sarajevo.20180515.232316.json', 'http://addlink.rome2rio.com/addlink2/?edit=EU\\Croatia.bus.Zagreb - Medjugorje.20180515.233557.json'], [504, 232], [['', '', '']], [], 'Addlink'], ['Toping Trade', '//static.r2r. ...
#
# 4 	 2 	 11
#
# 4 	 2 	 12 	 False
#
# 4 	 2 	 13 	 [[18, 'EUR', 18.35, 'False', ''], [22, 'EUR', 22.09, 'False', ''], [26, 'EUR', 25.4, 'False', '']]
#
# 4 	 2 	 14 	 [[130, 'HRK', 138.26, 'False', ''], [170, 'HRK', 166.42, 'False', ''], [200, 'HRK', 191.4, 'False', '']]
#
# 4 	 2 	 15 	 53
#
# 4 	 2 	 16 	 53
#
# 4 	 2 	 17 	 []
#
# 4 	 2 	 18 	 [[['station', 'Zagreb', 45.8038, 15.99288, 'HR', 'Europe/Zagreb'], 0, 0, 'False', 'False'], [['station', 'Novska', 45.33979, 16.97857, 'HR', 'Europe/Zagreb'], '', 60, 'True', 'False'], [['station', 'Bosanski Gradiska Zob', 45.14368, 17.25487, 'BA', 'Europe/Sarajevo'], 110, '', 'False', 'True'], [['station', 'Nova Topola', 45.05266, 17.30811, 'BA', 'Europe/Sarajevo'], 135, '', 'False', 'True'], [['station', 'Laktasi', 44.90677, 17.30172, 'BA', 'Europe/Sarajevo'], 155, '', 'False', 'True'], [['station', 'Banja Luka', 44.78816, 17.21033, 'BA', 'Europe/Sarajevo'], 165, '', 'False', 'True']]
#
# 4 	 2 	 19 	 []
#
# 4 	 2 	 20 	 []
#
# 4 	 2 	 21
#
# 4 	 2 	 22 	 []
#
# 4 	 2 	 23 	 []
#
# 4 	 3 	 0 	 transit
#
# 4 	 3 	 1 	 bus
#
# 4 	 3 	 2 	 orange
#
# 4 	 3 	 3 	 36000
#
# 4 	 3 	 4 	 3600
#
# 4 	 3 	 5 	 399.2974
#
# 4 	 3 	 6 	 ['station', 'Banja Luka', 44.7883, 17.21046, 'BA', 'Europe/Sarajevo']
#
# 4 	 3 	 7 	 ['station', 'Tivat', 42.43028, 18.70125, 'ME', 'Europe/Podgorica']
#
# 4 	 3 	 8
#
# 4 	 3 	 9 	 True
#
# 4 	 3 	 10 	 [36000, 399.2974, ['station', 'Banja Luka', 44.7883, 17.21046, 'BA', 'Europe/Sarajevo'], ['station', 'Tivat', 42.43028, 18.70125, 'ME', 'Europe/Podgorica'], 'bus', ['None'], '', 7, [['Bocac Tours', '//static.r2r.io/logos/Trains/96/_BOCA_TOURS_20161151358.png', 'http://www.bocactours.com', 'bocactours.com', 36000, 399.2974, 7, '', [['http://www.bocactours.com', 'bocactours.com', 'Schedules at', 'bocactours.com', '', '', '', '', '']], ['Seasonal line, operates from 01.06. until 31.08.'], '051/215-725', 'bocact@teol.net', '', [['//static.r2r.io/transitimages/1811084013.jpg', 333, 250], ['//static.r2r.io/transitimages/1186420075.jpg', 185, 250], ['//static.r2r.io/transitimages/750318910.jpg', 333, 250]], [], [[30, 'EUR', 32.02, 'False', ''], [40, 'EUR', 37.69, 'False', ''], [50, 'EUR', 46.92, 'False', '']], [['', '', ''], ['', '', ''], ['', '', '']], [], [], '_BOCA_TOURS', ['station', 'Banja Luka', 44.7883, 17.21046, 'BA', 'Europe/Sarajevo'], ['station', 'Tivat', 42.43028, 18.70125, 'ME', 'Europe/Podgorica'], [[['station', 'Banja Luka', 44.7883, 17.21046, 'BA', 'Europe/Sarajevo'], '', 55, 'True', 'False'], [['station', 'Mrkonjić Grad', 44.41284, 17.08209, 'BA', 'Europe/Sarajevo'], '', 135, 'True', 'False'], [['station', 'Herceg Novi', 42.45292, 18.53379, 'ME', 'Europe/Podgorica'], 595, '', 'False', 'True'], [['station', 'Tivat', 42.43028, 18.70125, 'ME', 'Europe/Podgorica'], 655, '', 'False', 'True']], '', ['http://addlink.rome2rio.com/addlink2/?edit=EU\\Bosnia and Herzegovina.bus.Prijedor - Bar.20131209.112720.json'], [7], [['', '', '']], [], 'Addlink']]]
#
# 4 	 3 	 11
#
# 4 	 3 	 12 	 False
#
# 4 	 3 	 13 	 [[30, 'EUR', 32.02, 'False', ''], [40, 'EUR', 37.69, 'False', ''], [50, 'EUR', 46.92, 'False', '']]
#
# 4 	 3 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 4 	 3 	 15 	 53
#
# 4 	 3 	 16 	 53
#
# 4 	 3 	 17 	 []
#
# 4 	 3 	 18 	 [[['station', 'Banja Luka', 44.7883, 17.21046, 'BA', 'Europe/Sarajevo'], '', 55, 'True', 'False'], [['station', 'Mrkonjić Grad', 44.41284, 17.08209, 'BA', 'Europe/Sarajevo'], '', 135, 'True', 'False'], [['station', 'Herceg Novi', 42.45292, 18.53379, 'ME', 'Europe/Podgorica'], 595, '', 'False', 'True'], [['station', 'Tivat', 42.43028, 18.70125, 'ME', 'Europe/Podgorica'], 655, '', 'False', 'True']]
#
# 4 	 3 	 19 	 []
#
# 4 	 3 	 20 	 []
#
# 4 	 3 	 21
#
# 4 	 3 	 22 	 []
#
# 4 	 3 	 23 	 []
#
# path # 5
#
# 5 	 0 	 0 	 transit
#
# 5 	 0 	 1 	 bus
#
# 5 	 0 	 2 	 orange
#
# 5 	 0 	 3 	 78000
#
# 5 	 0 	 4 	 3600
#
# 5 	 0 	 5 	 1537.936
#
# 5 	 0 	 6 	 ['station', 'Marseille Train Station Saint Charles', 43.304, 5.379966, 'FR', 'Europe/Paris']
#
# 5 	 0 	 7 	 ['station', 'Belgrad Central Bus Station', 44.81018, 20.4544, 'RS', 'Europe/Belgrade']
#
# 5 	 0 	 8
#
# 5 	 0 	 9 	 True
#
# 5 	 0 	 10 	 [78000, 1537.936, ['station', 'Marseille Train Station Saint Charles', 43.304, 5.379966, 'FR', 'Europe/Paris'], ['station', 'Belgrad Central Bus Station', 44.81018, 20.4544, 'RS', 'Europe/Belgrade'], 'bus', ['Commuter', ' Bicycles', ' Wheelchair'], 'SP Lasta AD Beograd', 1, [['Lasta', '//static.r2r.io/logos/Trains/96/lasta.png', 'http://lasta.rs', 'lasta.rs', 78000, 1537.936, 1, 'SP Lasta AD Beograd', [['https://lasta.rs/', 'Lasta', 'Website', 'Lasta', '', '', '', '', '']], [], '', '', '', [['//static.r2r.io/transitimages/1422141735.jpg', 333, 250], ['//static.r2r.io/transitimages/1505478559.jpg', 375, 250], ['//static.r2r.io/transitimages/1664897677.jpg', 333, 250], ['//static.r2r.io/transitimages/771283186.jpg', 350, 250], ['//static.r2r.io/transitimages/1923257757.jpg', 333, 250], ['//static.r2r.io/transitimages/396465745.jpg', 417, 250], ['//static.r2r.io/transitimages/542530284.jpg', 593, 250]], [[['SP Lasta AD Beograd'], [1, 0, 0, 0], ['Advance booking: <b>Not Required</b>.']]], [[55, 'EUR', 54.96, 'False', ''], [60, 'EUR', 61.28, 'False', ''], [70, 'EUR', 68.22, 'False', '']], [[6000, 'RSD', 6450.89, 'False', ''], [7000, 'RSD', 7192.18, 'False', ''], [8000, 'RSD', 8006.47, 'False', '']], [], [], '_LASTA', ['station', 'Marseille Train Station Saint Charles', 43.304, 5.379966, 'FR', 'Europe/Paris'], ['station', 'Belgrad Central Bus Station', 44.81018, 20.4544, 'RS', 'Europe/Belgrade'], [[['station', 'Marseille Train Station Saint Charles', 43.304, 5.379966, 'FR', 'Europe/Paris'], '', 180, 'True', 'False'], [['station', 'Toulon Central Bus Station', 43.1278, 5.930755, 'FR', 'Europe/Paris'], '', 250, 'True', 'False'], [['station', 'Nice Boulevard Rene Cassin', 43.66779, 7.209463, 'FR', 'Europe/Paris'], '', 350, 'True', 'False'], [['station', 'Belgrad Central Bus Station', 44.81018, 20.4544, 'RS', 'Europe/Belgrade'], 1480, '', 'False', 'True']], '', [], [], [['SP Lasta AD Beograd', '2C4365', 'FFFFFF']], [], 'Gtfs']]]
#
# 5 	 0 	 11
#
# 5 	 0 	 12 	 False
#
# 5 	 0 	 13 	 [[55, 'EUR', 54.96, 'False', ''], [60, 'EUR', 61.28, 'False', ''], [70, 'EUR', 68.22, 'False', '']]
#
# 5 	 0 	 14 	 [[6000, 'RSD', 6450.89, 'False', ''], [7000, 'RSD', 7192.18, 'False', ''], [8000, 'RSD', 8006.47, 'False', '']]
#
# 5 	 0 	 15 	 53
#
# 5 	 0 	 16 	 53
#
# 5 	 0 	 17 	 []
#
# 5 	 0 	 18 	 [[['station', 'Marseille Train Station Saint Charles', 43.304, 5.379966, 'FR', 'Europe/Paris'], '', 180, 'True', 'False'], [['station', 'Toulon Central Bus Station', 43.1278, 5.930755, 'FR', 'Europe/Paris'], '', 250, 'True', 'False'], [['station', 'Nice Boulevard Rene Cassin', 43.66779, 7.209463, 'FR', 'Europe/Paris'], '', 350, 'True', 'False'], [['station', 'Belgrad Central Bus Station', 44.81018, 20.4544, 'RS', 'Europe/Belgrade'], 1480, '', 'False', 'True']]
#
# 5 	 0 	 19 	 []
#
# 5 	 0 	 20 	 []
#
# 5 	 0 	 21
#
# 5 	 0 	 22 	 []
#
# 5 	 0 	 23 	 []
#
# 5 	 1 	 0 	 transit
#
# 5 	 1 	 1 	 bus
#
# 5 	 1 	 2 	 orange
#
# 5 	 1 	 3 	 44100
#
# 5 	 1 	 4 	 3600
#
# 5 	 1 	 5 	 526.5655
#
# 5 	 1 	 6 	 ['station', 'Belgrade', 44.81007, 20.45434, 'RS', 'Europe/Belgrade']
#
# 5 	 1 	 7 	 ['station', 'Tivat', 42.4362, 18.69801, 'ME', 'Europe/Podgorica']
#
# 5 	 1 	 8
#
# 5 	 1 	 9 	 True
#
# 5 	 1 	 10 	 [44100, 526.5655, ['station', 'Belgrade', 44.81007, 20.45434, 'RS', 'Europe/Belgrade'], ['station', 'Tivat', 42.4362, 18.69801, 'ME', 'Europe/Podgorica'], 'bus', ['None'], '', 8, [['Banbus', '//static.r2r.io/logos/Trains/96/Banbus.png', 'https://banbus.co.rs/', 'banbus.co.rs', 44100, 526.5655, 8, '', [['https://banbus.co.rs/red-voznje.html', 'banbus.co.rs', 'Schedules at', 'banbus.co.rs', '', '', '', '', '']], [], '+381 11 362 5555', 'ffice@banbus.co.rs', '', [['//static.r2r.io/transitimages/872721833.jpg', 448, 250], ['//static.r2r.io/transitimages/1274629216.jpg', 333, 250], ['//static.r2r.io/transitimages/1375582261.jpg', 250, 250], ['//static.r2r.io/transitimages/862600487.jpg', 391, 250], ['//static.r2r.io/transitimages/310801445.jpg', 333, 250]], [], [[27, 'EUR', 26.86, 'False', ''], [27, 'EUR', 26.86, 'False', ''], [27, 'EUR', 26.86, 'False', '']], [[3153, 'RSD', 3152.98, 'False', ''], [3153, 'RSD', 3152.98, 'False', ''], [3153, 'RSD', 3152.98, 'False', '']], [], [], '_BANBUS', ['station', 'Belgrade', 44.81007, 20.45434, 'RS', 'Europe/Belgrade'], ['station', 'Tivat', 42.4362, 18.69801, 'ME', 'Europe/Podgorica'], [[['station', 'Belgrade', 44.81007, 20.45434, 'RS', 'Europe/Belgrade'], 0, 0, 'False', 'False'], [['station', 'Gornji Milanovac', 44.02145, 20.46152, 'RS', 'Europe/Belgrade'], '', 120, 'True', 'False'], [['station', 'Podgorica', 42.43232, 19.26819, 'ME', 'Europe/Podgorica'], 570, '', 'False', 'True'], [['station', 'Sutomore', 42.14132, 19.04767, 'ME', 'Europe/Podgorica'], 630, '', 'False', 'True'], [['station', 'Petrovac', 42.20758, 18.94561, 'ME', 'Europe/Podgorica'], 660, '', 'False', 'True'], [['station', 'Budva', 42.29014, 18.83915, 'ME', 'Europe/Podgorica'], 675, '', 'False', 'True'], [['station', 'Tivat', 42.4362, 18.69801, 'ME', 'Europe/Podgorica'], 735, '', 'False', 'True']], '', ['http://addlink.rome2rio.com/addlink2/?edit=EU\\Serbia.bus.Belgrade - Herceg Novi.20151216.173322.json'], [509], [['', '', '']], [], 'Addlink']]]
#
# 5 	 1 	 11
#
# 5 	 1 	 12 	 False
#
# 5 	 1 	 13 	 [[27, 'EUR', 26.86, 'False', ''], [27, 'EUR', 26.86, 'False', ''], [27, 'EUR', 26.86, 'False', '']]
#
# 5 	 1 	 14 	 [[3153, 'RSD', 3152.98, 'False', ''], [3153, 'RSD', 3152.98, 'False', ''], [3153, 'RSD', 3152.98, 'False', '']]
#
# 5 	 1 	 15 	 53
#
# 5 	 1 	 16 	 53
#
# 5 	 1 	 17 	 []
#
# 5 	 1 	 18 	 [[['station', 'Belgrade', 44.81007, 20.45434, 'RS', 'Europe/Belgrade'], 0, 0, 'False', 'False'], [['station', 'Gornji Milanovac', 44.02145, 20.46152, 'RS', 'Europe/Belgrade'], '', 120, 'True', 'False'], [['station', 'Podgorica', 42.43232, 19.26819, 'ME', 'Europe/Podgorica'], 570, '', 'False', 'True'], [['station', 'Sutomore', 42.14132, 19.04767, 'ME', 'Europe/Podgorica'], 630, '', 'False', 'True'], [['station', 'Petrovac', 42.20758, 18.94561, 'ME', 'Europe/Podgorica'], 660, '', 'False', 'True'], [['station', 'Budva', 42.29014, 18.83915, 'ME', 'Europe/Podgorica'], 675, '', 'False', 'True'], [['station', 'Tivat', 42.4362, 18.69801, 'ME', 'Europe/Podgorica'], 735, '', 'False', 'True']]
#
# 5 	 1 	 19 	 []
#
# 5 	 1 	 20 	 []
#
# 5 	 1 	 21
#
# 5 	 1 	 22 	 []
#
# 5 	 1 	 23 	 []
#
# path # 6
#
# 6 	 0 	 0 	 car
#
# 6 	 0 	 1 	 car
#
# 6 	 0 	 2 	 grey-darker
#
# 6 	 0 	 3 	 63974.493
#
# 6 	 0 	 4 	 0
#
# 6 	 0 	 5 	 1686.286
#
# 6 	 0 	 6 	 ['node', 'Marseille', 43.29695, 5.38107, 'FR', 'Europe/Paris', 2.5]
#
# 6 	 0 	 7 	 ['node', 'Tivat', 42.42888, 18.70009, 'ME', 'Europe/Podgorica', 0.5]
#
# 6 	 0 	 8
#
# 6 	 0 	 9 	 True
#
# 6 	 0 	 10
#
# 6 	 0 	 11
#
# 6 	 0 	 12 	 False
#
# 6 	 0 	 13 	 [[270, 'EUR', 279.1, 'False', ''], [340, 'EUR', 341.12, 'False', ''], [410, 'EUR', 403.14, 'False', '']]
#
# 6 	 0 	 14 	 [['', '', ''], ['', '', ''], ['', '', '']]
#
# 6 	 0 	 15 	 53
#
# 6 	 0 	 16 	 53
#
# 6 	 0 	 17 	 []
#
# 6 	 0 	 18 	 []
#
# 6 	 0 	 19 	 [['Small vehicle', [[280, 'EUR', 279.1, 'False', ''], [280, 'EUR', 279.1, 'False', ''], [280, 'EUR', 279.1, 'False', '']]], ['Medium vehicle', [[342, 'EUR', 341.12, 'False', ''], [342, 'EUR', 341.12, 'False', ''], [342, 'EUR', 341.12, 'False', '']]], ['Large vehicle', [[404, 'EUR', 403.14, 'False', ''], [404, 'EUR', 403.14, 'False', ''], [404, 'EUR', 403.14, 'False', '']]]]
#
# 6 	 0 	 20 	 []
#
# 6 	 0 	 21
#
# 6 	 0 	 22
#
# 6 	 0 	 23 	 []
